# %% [markdown]
# # About
#
# Convert deeplabv3_mnv2_ade20k_train_2018_12_03 to Core ML
#
# Model is quantized to 8 bits. On iPhone Xs, latency reduced from 790 ms (no quantization) to 220 ms. Using tfcoreml to optimize the TF graph, the latency reduces further to 150 ms.
#
#
# Note: tfcoreml rebuild the TF graph then use coremltools to convert to Core ML format.

# %% [markdown]
# # Download model and setup enviroments

# %%
# !wget http://download.tensorflow.org/models/deeplabv3_mnv2_ade20k_train_2018_12_03.tar.gz
# !tar -zxvf deeplabv3_mnv2_ade20k_train_2018_12_03.tar.gz
# Out:
# --2021-08-11 18:37:34--  http://download.tensorflow.org/models/deeplabv3_mnv2_ade20k_train_2018_12_03.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.33.208, 2607:f8b0:4004:837::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.33.208|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26028742 (25M) [application/x-tar]
# Saving to: ‘deeplabv3_mnv2_ade20k_train_2018_12_03.tar.gz’
#
# deeplabv3_mnv2_ade2 100%[===================>]  24.82M  83.4MB/s    in 0.3s
#
# 2021-08-11 18:37:34 (83.4 MB/s) - ‘deeplabv3_mnv2_ade20k_train_2018_12_03.tar.gz’ saved [26028742/26028742]
#
# deeplabv3_mnv2_ade20k_train_2018_12_03/
# deeplabv3_mnv2_ade20k_train_2018_12_03/model.ckpt.index
# deeplabv3_mnv2_ade20k_train_2018_12_03/frozen_inference_graph.pb
# deeplabv3_mnv2_ade20k_train_2018_12_03/model.ckpt.data-00000-of-00001

# %%
# !pip install coremltools==4.1
# !pip install tfcoreml==2.0.0
# Out:
# Collecting coremltools==4.1
#   Downloading coremltools-4.1-cp37-none-manylinux1_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 33.8 MB/s
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (4.41.1)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (3.17.3)
# Requirement already satisfied: numpy<1.20,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.19.5)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (21.2.0)
# Collecting attr
#   Downloading attr-0.3.1.tar.gz (1.7 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->coremltools==4.1) (2.4.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->coremltools==4.1) (1.2.1)
# Building wheels for collected packages: attr
#   Building wheel for attr (setup.py) ... done
#   Created wheel for attr: filename=attr-0.3.1-py3-none-any.whl size=2457 sha256=48ef7587a74e15441992f927a5fabed213c3774817e95a5c0ca6a10918db28d7
#   Stored in directory: /root/.cache/pip/wheels/3b/5d/58/41fbe92f47031641008bd8559ee89e58bf0f123f9c18dea1cb
# Successfully built attr
# Installing collected packages: attr, coremltools
# Successfully installed attr-0.3.1 coremltools-4.1
# Collecting tfcoreml==2.0.0
#   Downloading tfcoreml-2.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.7 MB/s
# Collecting tensorflow<=1.14,>=1.5.0
#   Downloading tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3 MB)
#      |████████████████████████████████| 109.3 MB 17 kB/s
# Requirement already satisfied: coremltools>=0.8 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (4.1)
# Requirement already satisfied: numpy>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (1.19.5)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (1.15.0)
# Requirement already satisfied: attr in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (0.3.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (21.2.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (1.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (21.0)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.3 MB/s
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 49.1 MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.8.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.34.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.1.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.36.2)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488 kB)
#      |████████████████████████████████| 488 kB 69.3 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (57.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (4.6.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->coremltools>=0.8->tfcoreml==2.0.0) (2.4.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->coremltools>=0.8->tfcoreml==2.0.0) (1.2.1)
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, tensorflow, tfcoreml
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.5 requires tensorflow>=2.0.0, but you have tensorflow 1.14.0 which is incompatible.
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 tfcoreml-2.0

# %%
import sys
print(sys.version)

import tensorflow as tf
print(tf.__version__)

import coremltools as ct
print(ct.__version__)
# Out:
# 3.7.11 (default, Jul  3 2021, 18:01:19)
# [GCC 7.5.0]
# 1.14.0
# 4.1

# %%
def load_frozen_graph(path):
  with tf.io.gfile.GFile(path, "rb") as f:
    graph_def = tf.compat.v1.GraphDef()
    graph_def.ParseFromString(f.read())

    return graph_def

def export_ops_name(the_graph, filename):
  with open(filename, "w") as text_file:
    ops = the_graph.get_operations()
    N = len(ops)
    for i in range(N):
      text_file.write('\n\nop id {} , op type: "{}"'.format(str(i), ops[i].type))
      
      text_file.write('\ninput(s):'),
      for x in ops[i].inputs:
        text_file.write("name = {}, shape: {}, ".format(x.name, x.get_shape()))
      
      text_file.write('\noutput(s):'),
      for x in ops[i].outputs:
        text_file.write("name = {}, shape: {},".format(x.name, x.get_shape()))
  print('Exported to:', filename)


input_file = '/content/deeplabv3_mnv2_ade20k_train_2018_12_03/frozen_inference_graph.pb'
model_name = 'deeplabv3_mnv2_ade20k_train_2018_12_03'
with tf.Session(graph=tf.Graph()) as sess:
  graph_def = load_frozen_graph(input_file)
  tf.import_graph_def(graph_def, name="")
  the_graph = tf.compat.v1.get_default_graph()
  export_ops_name(the_graph, f'{model_name}_ops.txt')
# Out:
# Exported to: deeplabv3_mnv2_ade20k_train_2018_12_03_ops.txt

# %%
import tfcoreml
import coremltools as ct

# Convert the TensorFlow model to Core ML.

input_path = "/content/deeplabv3_mnv2_ade20k_train_2018_12_03/frozen_inference_graph.pb"
output_path = "DeepLabV3_no_metadata.mlmodel"

input_tensor = "ImageTensor:0"
input_name = "ImageTensor__0"
output_tensor = "ArgMax:0"

coreml_model = tfcoreml.convert(
    tf_model_path=input_path,
    mlmodel_path=output_path,
    output_feature_names=[output_tensor],
    input_name_shape_dict={input_tensor: [1, 513, 513, 3]},
    image_input_names=input_name)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# Collecting all the 'Const' ops from the graph, by running it....
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob ImageTensor:0
# 1/1034: Analysing op name: ExpandDims_1/dim ( type:  Const )
# 2/1034: Analysing op name: Slice/size/0 ( type:  Const )
# 3/1034: Analysing op name: Slice/begin ( type:  Const )
# 4/1034: Analysing op name: strided_slice_8/stack_2 ( type:  Const )
# 5/1034: Analysing op name: strided_slice_8/stack_1 ( type:  Const )
# 6/1034: Analysing op name: strided_slice_8/stack ( type:  Const )
# 7/1034: Analysing op name: strided_slice_7/stack_2 ( type:  Const )
# 8/1034: Analysing op name: strided_slice_7/stack_1 ( type:  Const )
# 9/1034: Analysing op name: strided_slice_7/stack ( type:  Const )
# 10/1034: Analysing op name: ArgMax/dimension ( type:  Const )
# 11/1034: Analysing op name: strided_slice_6/stack_2 ( type:  Const )
# 12/1034: Analysing op name: strided_slice_6/stack_1 ( type:  Const )
# 13/1034: Analysing op name: strided_slice_6/stack ( type:  Const )
# 14/1034: Analysing op name: Shape_4 ( type:  Const )
# 15/1034: Analysing op name: strided_slice_6 ( type:  StridedSlice )
# 16/1034: Analysing op name: ResizeBilinear_1/size ( type:  Const )
# 17/1034: Analysing op name: logits/semantic/biases ( type:  Const )
# 18/1034: Analysing op name: logits/semantic/biases/read ( type:  Identity )
# 19/1034: Analysing op name: logits/semantic/weights ( type:  Const )
# 20/1034: Analysing op name: logits/semantic/weights/read ( type:  Identity )
# 21/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/moving_variance ( type:  Const )
# 22/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/moving_variance/read ( type:  Identity )
# 23/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/moving_mean ( type:  Const )
# 24/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/moving_mean/read ( type:  Identity )
# 25/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/beta ( type:  Const )
# 26/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/beta/read ( type:  Identity )
# 27/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/gamma ( type:  Const )
# 28/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/gamma/read ( type:  Identity )
# 29/1034: Analysing op name: decoder/decoder_conv1_pointwise/weights ( type:  Const )
# 30/1034: Analysing op name: decoder/decoder_conv1_pointwise/weights/read ( type:  Identity )
# 31/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/moving_variance ( type:  Const )
# 32/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 33/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/moving_mean ( type:  Const )
# 34/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 35/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/beta ( type:  Const )
# 36/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/beta/read ( type:  Identity )
# 37/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/gamma ( type:  Const )
# 38/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 39/1034: Analysing op name: decoder/decoder_conv1_depthwise/depthwise_weights ( type:  Const )
# 40/1034: Analysing op name: decoder/decoder_conv1_depthwise/depthwise_weights/read ( type:  Identity )
# 41/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/moving_variance ( type:  Const )
# 42/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/moving_variance/read ( type:  Identity )
# 43/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/moving_mean ( type:  Const )
# 44/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/moving_mean/read ( type:  Identity )
# 45/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/beta ( type:  Const )
# 46/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/beta/read ( type:  Identity )
# 47/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/gamma ( type:  Const )
# 48/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/gamma/read ( type:  Identity )
# 49/1034: Analysing op name: decoder/decoder_conv0_pointwise/weights ( type:  Const )
# 50/1034: Analysing op name: decoder/decoder_conv0_pointwise/weights/read ( type:  Identity )
# 51/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/moving_variance ( type:  Const )
# 52/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 53/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/moving_mean ( type:  Const )
# 54/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 55/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/beta ( type:  Const )
# 56/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/beta/read ( type:  Identity )
# 57/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/gamma ( type:  Const )
# 58/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 59/1034: Analysing op name: decoder/decoder_conv0_depthwise/depthwise_weights ( type:  Const )
# 60/1034: Analysing op name: decoder/decoder_conv0_depthwise/depthwise_weights/read ( type:  Identity )
# 61/1034: Analysing op name: decoder/concat/axis ( type:  Const )
# 62/1034: Analysing op name: decoder/ResizeBilinear_1/size ( type:  Const )
# 63/1034: Analysing op name: decoder/ResizeBilinear/size ( type:  Const )
# 64/1034: Analysing op name: decoder/feature_projection0/BatchNorm/moving_variance ( type:  Const )
# 65/1034: Analysing op name: decoder/feature_projection0/BatchNorm/moving_variance/read ( type:  Identity )
# 66/1034: Analysing op name: decoder/feature_projection0/BatchNorm/moving_mean ( type:  Const )
# 67/1034: Analysing op name: decoder/feature_projection0/BatchNorm/moving_mean/read ( type:  Identity )
# 68/1034: Analysing op name: decoder/feature_projection0/BatchNorm/beta ( type:  Const )
# 69/1034: Analysing op name: decoder/feature_projection0/BatchNorm/beta/read ( type:  Identity )
# 70/1034: Analysing op name: decoder/feature_projection0/BatchNorm/gamma ( type:  Const )
# 71/1034: Analysing op name: decoder/feature_projection0/BatchNorm/gamma/read ( type:  Identity )
# 72/1034: Analysing op name: decoder/feature_projection0/weights ( type:  Const )
# 73/1034: Analysing op name: decoder/feature_projection0/weights/read ( type:  Identity )
# 74/1034: Analysing op name: concat_projection/BatchNorm/moving_variance ( type:  Const )
# 75/1034: Analysing op name: concat_projection/BatchNorm/moving_variance/read ( type:  Identity )
# 76/1034: Analysing op name: concat_projection/BatchNorm/moving_mean ( type:  Const )
# 77/1034: Analysing op name: concat_projection/BatchNorm/moving_mean/read ( type:  Identity )
# 78/1034: Analysing op name: concat_projection/BatchNorm/beta ( type:  Const )
# 79/1034: Analysing op name: concat_projection/BatchNorm/beta/read ( type:  Identity )
# 80/1034: Analysing op name: concat_projection/BatchNorm/gamma ( type:  Const )
# 81/1034: Analysing op name: concat_projection/BatchNorm/gamma/read ( type:  Identity )
# 82/1034: Analysing op name: concat_projection/weights ( type:  Const )
# 83/1034: Analysing op name: concat_projection/weights/read ( type:  Identity )
# 84/1034: Analysing op name: concat/axis ( type:  Const )
# 85/1034: Analysing op name: aspp0/BatchNorm/moving_variance ( type:  Const )
# 86/1034: Analysing op name: aspp0/BatchNorm/moving_variance/read ( type:  Identity )
# 87/1034: Analysing op name: aspp0/BatchNorm/moving_mean ( type:  Const )
# 88/1034: Analysing op name: aspp0/BatchNorm/moving_mean/read ( type:  Identity )
# 89/1034: Analysing op name: aspp0/BatchNorm/beta ( type:  Const )
# 90/1034: Analysing op name: aspp0/BatchNorm/beta/read ( type:  Identity )
# 91/1034: Analysing op name: aspp0/BatchNorm/gamma ( type:  Const )
# 92/1034: Analysing op name: aspp0/BatchNorm/gamma/read ( type:  Identity )
# 93/1034: Analysing op name: aspp0/weights ( type:  Const )
# 94/1034: Analysing op name: aspp0/weights/read ( type:  Identity )
# 95/1034: Analysing op name: ResizeBilinear/size ( type:  Const )
# 96/1034: Analysing op name: image_pooling/BatchNorm/moving_variance ( type:  Const )
# 97/1034: Analysing op name: image_pooling/BatchNorm/moving_variance/read ( type:  Identity )
# 98/1034: Analysing op name: image_pooling/BatchNorm/moving_mean ( type:  Const )
# 99/1034: Analysing op name: image_pooling/BatchNorm/moving_mean/read ( type:  Identity )
# 100/1034: Analysing op name: image_pooling/BatchNorm/beta ( type:  Const )
# 101/1034: Analysing op name: image_pooling/BatchNorm/beta/read ( type:  Identity )
# 102/1034: Analysing op name: image_pooling/BatchNorm/gamma ( type:  Const )
# 103/1034: Analysing op name: image_pooling/BatchNorm/gamma/read ( type:  Identity )
# 104/1034: Analysing op name: image_pooling/weights ( type:  Const )
# 105/1034: Analysing op name: image_pooling/weights/read ( type:  Identity )
# 106/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance ( type:  Const )
# 107/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read ( type:  Identity )
# 108/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean ( type:  Const )
# 109/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read ( type:  Identity )
# 110/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/beta ( type:  Const )
# 111/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read ( type:  Identity )
# 112/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/gamma ( type:  Const )
# 113/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read ( type:  Identity )
# 114/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/weights ( type:  Const )
# 115/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/weights/read ( type:  Identity )
# 116/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance ( type:  Const )
# 117/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 118/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean ( type:  Const )
# 119/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 120/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta ( type:  Const )
# 121/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read ( type:  Identity )
# 122/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma ( type:  Const )
# 123/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 124/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 125/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 126/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 127/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 128/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise_weights ( type:  Const )
# 129/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise_weights/read ( type:  Identity )
# 130/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance ( type:  Const )
# 131/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 132/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean ( type:  Const )
# 133/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 134/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/beta ( type:  Const )
# 135/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/beta/read ( type:  Identity )
# 136/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/gamma ( type:  Const )
# 137/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/gamma/read ( type:  Identity )
# 138/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/weights ( type:  Const )
# 139/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/weights/read ( type:  Identity )
# 140/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/moving_variance ( type:  Const )
# 141/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/moving_variance/read ( type:  Identity )
# 142/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/moving_mean ( type:  Const )
# 143/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/moving_mean/read ( type:  Identity )
# 144/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/beta ( type:  Const )
# 145/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/beta/read ( type:  Identity )
# 146/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/gamma ( type:  Const )
# 147/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/gamma/read ( type:  Identity )
# 148/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/weights ( type:  Const )
# 149/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/weights/read ( type:  Identity )
# 150/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_variance ( type:  Const )
# 151/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 152/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_mean ( type:  Const )
# 153/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 154/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/beta ( type:  Const )
# 155/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/beta/read ( type:  Identity )
# 156/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/gamma ( type:  Const )
# 157/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 158/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 159/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 160/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 161/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 162/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise_weights ( type:  Const )
# 163/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise_weights/read ( type:  Identity )
# 164/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_variance ( type:  Const )
# 165/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 166/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_mean ( type:  Const )
# 167/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 168/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/beta ( type:  Const )
# 169/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/beta/read ( type:  Identity )
# 170/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/gamma ( type:  Const )
# 171/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/gamma/read ( type:  Identity )
# 172/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/weights ( type:  Const )
# 173/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/weights/read ( type:  Identity )
# 174/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/moving_variance ( type:  Const )
# 175/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/moving_variance/read ( type:  Identity )
# 176/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/moving_mean ( type:  Const )
# 177/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/moving_mean/read ( type:  Identity )
# 178/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/beta ( type:  Const )
# 179/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/beta/read ( type:  Identity )
# 180/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/gamma ( type:  Const )
# 181/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/gamma/read ( type:  Identity )
# 182/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/weights ( type:  Const )
# 183/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/weights/read ( type:  Identity )
# 184/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/moving_variance ( type:  Const )
# 185/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 186/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/moving_mean ( type:  Const )
# 187/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 188/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/beta ( type:  Const )
# 189/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/beta/read ( type:  Identity )
# 190/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/gamma ( type:  Const )
# 191/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 192/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 193/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 194/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 195/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 196/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise_weights ( type:  Const )
# 197/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise_weights/read ( type:  Identity )
# 198/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/moving_variance ( type:  Const )
# 199/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 200/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/moving_mean ( type:  Const )
# 201/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 202/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/beta ( type:  Const )
# 203/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/beta/read ( type:  Identity )
# 204/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/gamma ( type:  Const )
# 205/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/gamma/read ( type:  Identity )
# 206/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/weights ( type:  Const )
# 207/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/weights/read ( type:  Identity )
# 208/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/moving_variance ( type:  Const )
# 209/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/moving_variance/read ( type:  Identity )
# 210/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/moving_mean ( type:  Const )
# 211/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/moving_mean/read ( type:  Identity )
# 212/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/beta ( type:  Const )
# 213/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/beta/read ( type:  Identity )
# 214/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/gamma ( type:  Const )
# 215/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/gamma/read ( type:  Identity )
# 216/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/weights ( type:  Const )
# 217/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/weights/read ( type:  Identity )
# 218/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/moving_variance ( type:  Const )
# 219/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 220/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/moving_mean ( type:  Const )
# 221/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 222/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/beta ( type:  Const )
# 223/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/beta/read ( type:  Identity )
# 224/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/gamma ( type:  Const )
# 225/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 226/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 227/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 228/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 229/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 230/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise_weights ( type:  Const )
# 231/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise_weights/read ( type:  Identity )
# 232/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/moving_variance ( type:  Const )
# 233/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 234/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/moving_mean ( type:  Const )
# 235/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 236/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/beta ( type:  Const )
# 237/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/beta/read ( type:  Identity )
# 238/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/gamma ( type:  Const )
# 239/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/gamma/read ( type:  Identity )
# 240/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/weights ( type:  Const )
# 241/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/weights/read ( type:  Identity )
# 242/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/moving_variance ( type:  Const )
# 243/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/moving_variance/read ( type:  Identity )
# 244/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/moving_mean ( type:  Const )
# 245/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/moving_mean/read ( type:  Identity )
# 246/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/beta ( type:  Const )
# 247/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/beta/read ( type:  Identity )
# 248/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/gamma ( type:  Const )
# 249/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/gamma/read ( type:  Identity )
# 250/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/weights ( type:  Const )
# 251/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/weights/read ( type:  Identity )
# 252/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/moving_variance ( type:  Const )
# 253/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 254/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/moving_mean ( type:  Const )
# 255/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 256/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/beta ( type:  Const )
# 257/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/beta/read ( type:  Identity )
# 258/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/gamma ( type:  Const )
# 259/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 260/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 261/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 262/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 263/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 264/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise_weights ( type:  Const )
# 265/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise_weights/read ( type:  Identity )
# 266/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/moving_variance ( type:  Const )
# 267/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 268/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/moving_mean ( type:  Const )
# 269/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 270/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/beta ( type:  Const )
# 271/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/beta/read ( type:  Identity )
# 272/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/gamma ( type:  Const )
# 273/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/gamma/read ( type:  Identity )
# 274/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/weights ( type:  Const )
# 275/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/weights/read ( type:  Identity )
# 276/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/moving_variance ( type:  Const )
# 277/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/moving_variance/read ( type:  Identity )
# 278/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/moving_mean ( type:  Const )
# 279/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/moving_mean/read ( type:  Identity )
# 280/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/beta ( type:  Const )
# 281/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/beta/read ( type:  Identity )
# 282/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/gamma ( type:  Const )
# 283/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/gamma/read ( type:  Identity )
# 284/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/weights ( type:  Const )
# 285/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/weights/read ( type:  Identity )
# 286/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/moving_variance ( type:  Const )
# 287/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 288/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/moving_mean ( type:  Const )
# 289/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 290/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/beta ( type:  Const )
# 291/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/beta/read ( type:  Identity )
# 292/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/gamma ( type:  Const )
# 293/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 294/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 295/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 296/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 297/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 298/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise_weights ( type:  Const )
# 299/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise_weights/read ( type:  Identity )
# 300/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/moving_variance ( type:  Const )
# 301/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 302/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/moving_mean ( type:  Const )
# 303/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 304/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/beta ( type:  Const )
# 305/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/beta/read ( type:  Identity )
# 306/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/gamma ( type:  Const )
# 307/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/gamma/read ( type:  Identity )
# 308/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/weights ( type:  Const )
# 309/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/weights/read ( type:  Identity )
# 310/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/moving_variance ( type:  Const )
# 311/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/moving_variance/read ( type:  Identity )
# 312/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/moving_mean ( type:  Const )
# 313/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/moving_mean/read ( type:  Identity )
# 314/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/beta ( type:  Const )
# 315/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/beta/read ( type:  Identity )
# 316/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/gamma ( type:  Const )
# 317/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/gamma/read ( type:  Identity )
# 318/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/weights ( type:  Const )
# 319/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/weights/read ( type:  Identity )
# 320/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/moving_variance ( type:  Const )
# 321/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 322/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/moving_mean ( type:  Const )
# 323/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 324/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/beta ( type:  Const )
# 325/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/beta/read ( type:  Identity )
# 326/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/gamma ( type:  Const )
# 327/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 328/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 329/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 330/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 331/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 332/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise_weights ( type:  Const )
# 333/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise_weights/read ( type:  Identity )
# 334/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/moving_variance ( type:  Const )
# 335/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 336/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/moving_mean ( type:  Const )
# 337/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 338/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/beta ( type:  Const )
# 339/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/beta/read ( type:  Identity )
# 340/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/gamma ( type:  Const )
# 341/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/gamma/read ( type:  Identity )
# 342/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/weights ( type:  Const )
# 343/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/weights/read ( type:  Identity )
# 344/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/moving_variance ( type:  Const )
# 345/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/moving_variance/read ( type:  Identity )
# 346/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/moving_mean ( type:  Const )
# 347/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/moving_mean/read ( type:  Identity )
# 348/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/beta ( type:  Const )
# 349/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/beta/read ( type:  Identity )
# 350/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/gamma ( type:  Const )
# 351/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/gamma/read ( type:  Identity )
# 352/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/weights ( type:  Const )
# 353/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/weights/read ( type:  Identity )
# 354/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/moving_variance ( type:  Const )
# 355/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 356/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/moving_mean ( type:  Const )
# 357/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 358/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/beta ( type:  Const )
# 359/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/beta/read ( type:  Identity )
# 360/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/gamma ( type:  Const )
# 361/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 362/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 363/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 364/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 365/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 366/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise_weights ( type:  Const )
# 367/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise_weights/read ( type:  Identity )
# 368/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/moving_variance ( type:  Const )
# 369/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 370/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/moving_mean ( type:  Const )
# 371/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 372/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/beta ( type:  Const )
# 373/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/beta/read ( type:  Identity )
# 374/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/gamma ( type:  Const )
# 375/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/gamma/read ( type:  Identity )
# 376/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/weights ( type:  Const )
# 377/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/weights/read ( type:  Identity )
# 378/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/moving_variance ( type:  Const )
# 379/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/moving_variance/read ( type:  Identity )
# 380/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/moving_mean ( type:  Const )
# 381/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/moving_mean/read ( type:  Identity )
# 382/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/beta ( type:  Const )
# 383/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/beta/read ( type:  Identity )
# 384/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/gamma ( type:  Const )
# 385/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/gamma/read ( type:  Identity )
# 386/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/weights ( type:  Const )
# 387/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/weights/read ( type:  Identity )
# 388/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/moving_variance ( type:  Const )
# 389/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 390/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/moving_mean ( type:  Const )
# 391/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 392/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/beta ( type:  Const )
# 393/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/beta/read ( type:  Identity )
# 394/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/gamma ( type:  Const )
# 395/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 396/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 397/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 398/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 399/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 400/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/depthwise_weights ( type:  Const )
# 401/1034: Analysing op name: MobilenetV2/expanded_conv_8/depthwise/depthwise_weights/read ( type:  Identity )
# 402/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/moving_variance ( type:  Const )
# 403/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 404/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/moving_mean ( type:  Const )
# 405/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 406/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/beta ( type:  Const )
# 407/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/beta/read ( type:  Identity )
# 408/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/gamma ( type:  Const )
# 409/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/BatchNorm/gamma/read ( type:  Identity )
# 410/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/weights ( type:  Const )
# 411/1034: Analysing op name: MobilenetV2/expanded_conv_8/expand/weights/read ( type:  Identity )
# 412/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/moving_variance ( type:  Const )
# 413/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/moving_variance/read ( type:  Identity )
# 414/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/moving_mean ( type:  Const )
# 415/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/moving_mean/read ( type:  Identity )
# 416/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/beta ( type:  Const )
# 417/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/beta/read ( type:  Identity )
# 418/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/gamma ( type:  Const )
# 419/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/BatchNorm/gamma/read ( type:  Identity )
# 420/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/weights ( type:  Const )
# 421/1034: Analysing op name: MobilenetV2/expanded_conv_7/project/weights/read ( type:  Identity )
# 422/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/moving_variance ( type:  Const )
# 423/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 424/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/moving_mean ( type:  Const )
# 425/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 426/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/beta ( type:  Const )
# 427/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/beta/read ( type:  Identity )
# 428/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/gamma ( type:  Const )
# 429/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 430/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/depthwise/BatchToSpaceND/crops ( type:  Const )
# 431/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/depthwise/BatchToSpaceND/block_shape ( type:  Const )
# 432/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/depthwise/SpaceToBatchND/paddings ( type:  Const )
# 433/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/depthwise/SpaceToBatchND/block_shape ( type:  Const )
# 434/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/depthwise_weights ( type:  Const )
# 435/1034: Analysing op name: MobilenetV2/expanded_conv_7/depthwise/depthwise_weights/read ( type:  Identity )
# 436/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/moving_variance ( type:  Const )
# 437/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 438/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/moving_mean ( type:  Const )
# 439/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 440/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/beta ( type:  Const )
# 441/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/beta/read ( type:  Identity )
# 442/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/gamma ( type:  Const )
# 443/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/BatchNorm/gamma/read ( type:  Identity )
# 444/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/weights ( type:  Const )
# 445/1034: Analysing op name: MobilenetV2/expanded_conv_7/expand/weights/read ( type:  Identity )
# 446/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/moving_variance ( type:  Const )
# 447/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/moving_variance/read ( type:  Identity )
# 448/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/moving_mean ( type:  Const )
# 449/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/moving_mean/read ( type:  Identity )
# 450/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/beta ( type:  Const )
# 451/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/beta/read ( type:  Identity )
# 452/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/gamma ( type:  Const )
# 453/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/BatchNorm/gamma/read ( type:  Identity )
# 454/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/weights ( type:  Const )
# 455/1034: Analysing op name: MobilenetV2/expanded_conv_6/project/weights/read ( type:  Identity )
# 456/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/moving_variance ( type:  Const )
# 457/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 458/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/moving_mean ( type:  Const )
# 459/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 460/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/beta ( type:  Const )
# 461/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/beta/read ( type:  Identity )
# 462/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/gamma ( type:  Const )
# 463/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 464/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/depthwise_weights ( type:  Const )
# 465/1034: Analysing op name: MobilenetV2/expanded_conv_6/depthwise/depthwise_weights/read ( type:  Identity )
# 466/1034: Analysing op name: MobilenetV2/expanded_conv_6/expand/BatchNorm/moving_variance ( type:  Const )
# 467/1034: Analysing op name: MobilenetV2/expanded_conv_6/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 468/1034: Analysing op name: MobilenetV2/expanded_conv_6/expand/BatchNorm/moving_mean ( type:  Const )
# ...
# 861/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/Conv2D ( type:  Conv2D )
# 862/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 863/1034: Analysing op name: MobilenetV2/expanded_conv_8/project/Identity ( type:  Identity )
# 864/1034: Analysing op name: MobilenetV2/expanded_conv_8/add ( type:  Add )
# 865/1034: Analysing op name: MobilenetV2/expanded_conv_8/output ( type:  Identity )
# 866/1034: Analysing op name: MobilenetV2/expanded_conv_9/input ( type:  Identity )
# 867/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/Conv2D ( type:  Conv2D )
# 868/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 869/1034: Analysing op name: MobilenetV2/expanded_conv_9/expand/Relu6 ( type:  Relu6 )
# 870/1034: Analysing op name: MobilenetV2/expanded_conv_9/expansion_output ( type:  Identity )
# 871/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 872/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 873/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 874/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 875/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise/Relu6 ( type:  Relu6 )
# 876/1034: Analysing op name: MobilenetV2/expanded_conv_9/depthwise_output ( type:  Identity )
# 877/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/Conv2D ( type:  Conv2D )
# 878/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 879/1034: Analysing op name: MobilenetV2/expanded_conv_9/project/Identity ( type:  Identity )
# 880/1034: Analysing op name: MobilenetV2/expanded_conv_9/add ( type:  Add )
# 881/1034: Analysing op name: MobilenetV2/expanded_conv_9/output ( type:  Identity )
# 882/1034: Analysing op name: MobilenetV2/expanded_conv_10/input ( type:  Identity )
# 883/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/Conv2D ( type:  Conv2D )
# 884/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 885/1034: Analysing op name: MobilenetV2/expanded_conv_10/expand/Relu6 ( type:  Relu6 )
# 886/1034: Analysing op name: MobilenetV2/expanded_conv_10/expansion_output ( type:  Identity )
# 887/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 888/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 889/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 890/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 891/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise/Relu6 ( type:  Relu6 )
# 892/1034: Analysing op name: MobilenetV2/expanded_conv_10/depthwise_output ( type:  Identity )
# 893/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/Conv2D ( type:  Conv2D )
# 894/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 895/1034: Analysing op name: MobilenetV2/expanded_conv_10/project/Identity ( type:  Identity )
# 896/1034: Analysing op name: MobilenetV2/expanded_conv_10/output ( type:  Identity )
# 897/1034: Analysing op name: MobilenetV2/expanded_conv_11/input ( type:  Identity )
# 898/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/Conv2D ( type:  Conv2D )
# 899/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 900/1034: Analysing op name: MobilenetV2/expanded_conv_11/expand/Relu6 ( type:  Relu6 )
# 901/1034: Analysing op name: MobilenetV2/expanded_conv_11/expansion_output ( type:  Identity )
# 902/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 903/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 904/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 905/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 906/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise/Relu6 ( type:  Relu6 )
# 907/1034: Analysing op name: MobilenetV2/expanded_conv_11/depthwise_output ( type:  Identity )
# 908/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/Conv2D ( type:  Conv2D )
# 909/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 910/1034: Analysing op name: MobilenetV2/expanded_conv_11/project/Identity ( type:  Identity )
# 911/1034: Analysing op name: MobilenetV2/expanded_conv_11/add ( type:  Add )
# 912/1034: Analysing op name: MobilenetV2/expanded_conv_11/output ( type:  Identity )
# 913/1034: Analysing op name: MobilenetV2/expanded_conv_12/input ( type:  Identity )
# 914/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/Conv2D ( type:  Conv2D )
# 915/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 916/1034: Analysing op name: MobilenetV2/expanded_conv_12/expand/Relu6 ( type:  Relu6 )
# 917/1034: Analysing op name: MobilenetV2/expanded_conv_12/expansion_output ( type:  Identity )
# 918/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 919/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 920/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 921/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 922/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise/Relu6 ( type:  Relu6 )
# 923/1034: Analysing op name: MobilenetV2/expanded_conv_12/depthwise_output ( type:  Identity )
# 924/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/Conv2D ( type:  Conv2D )
# 925/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 926/1034: Analysing op name: MobilenetV2/expanded_conv_12/project/Identity ( type:  Identity )
# 927/1034: Analysing op name: MobilenetV2/expanded_conv_12/add ( type:  Add )
# 928/1034: Analysing op name: MobilenetV2/expanded_conv_12/output ( type:  Identity )
# 929/1034: Analysing op name: MobilenetV2/expanded_conv_13/input ( type:  Identity )
# 930/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/Conv2D ( type:  Conv2D )
# 931/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 932/1034: Analysing op name: MobilenetV2/expanded_conv_13/expand/Relu6 ( type:  Relu6 )
# 933/1034: Analysing op name: MobilenetV2/expanded_conv_13/expansion_output ( type:  Identity )
# 934/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 935/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 936/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 937/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 938/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise/Relu6 ( type:  Relu6 )
# 939/1034: Analysing op name: MobilenetV2/expanded_conv_13/depthwise_output ( type:  Identity )
# 940/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/Conv2D ( type:  Conv2D )
# 941/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 942/1034: Analysing op name: MobilenetV2/expanded_conv_13/project/Identity ( type:  Identity )
# 943/1034: Analysing op name: MobilenetV2/expanded_conv_13/output ( type:  Identity )
# 944/1034: Analysing op name: MobilenetV2/expanded_conv_14/input ( type:  Identity )
# 945/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/Conv2D ( type:  Conv2D )
# 946/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 947/1034: Analysing op name: MobilenetV2/expanded_conv_14/expand/Relu6 ( type:  Relu6 )
# 948/1034: Analysing op name: MobilenetV2/expanded_conv_14/expansion_output ( type:  Identity )
# 949/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 950/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 951/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 952/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 953/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise/Relu6 ( type:  Relu6 )
# 954/1034: Analysing op name: MobilenetV2/expanded_conv_14/depthwise_output ( type:  Identity )
# 955/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/Conv2D ( type:  Conv2D )
# 956/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 957/1034: Analysing op name: MobilenetV2/expanded_conv_14/project/Identity ( type:  Identity )
# 958/1034: Analysing op name: MobilenetV2/expanded_conv_14/add ( type:  Add )
# 959/1034: Analysing op name: MobilenetV2/expanded_conv_14/output ( type:  Identity )
# 960/1034: Analysing op name: MobilenetV2/expanded_conv_15/input ( type:  Identity )
# 961/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/Conv2D ( type:  Conv2D )
# 962/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 963/1034: Analysing op name: MobilenetV2/expanded_conv_15/expand/Relu6 ( type:  Relu6 )
# 964/1034: Analysing op name: MobilenetV2/expanded_conv_15/expansion_output ( type:  Identity )
# 965/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 966/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 967/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 968/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 969/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise/Relu6 ( type:  Relu6 )
# 970/1034: Analysing op name: MobilenetV2/expanded_conv_15/depthwise_output ( type:  Identity )
# 971/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/Conv2D ( type:  Conv2D )
# 972/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 973/1034: Analysing op name: MobilenetV2/expanded_conv_15/project/Identity ( type:  Identity )
# 974/1034: Analysing op name: MobilenetV2/expanded_conv_15/add ( type:  Add )
# 975/1034: Analysing op name: MobilenetV2/expanded_conv_15/output ( type:  Identity )
# 976/1034: Analysing op name: MobilenetV2/expanded_conv_16/input ( type:  Identity )
# 977/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/Conv2D ( type:  Conv2D )
# 978/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 979/1034: Analysing op name: MobilenetV2/expanded_conv_16/expand/Relu6 ( type:  Relu6 )
# 980/1034: Analysing op name: MobilenetV2/expanded_conv_16/expansion_output ( type:  Identity )
# 981/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise/SpaceToBatchND ( type:  SpaceToBatchND )
# 982/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 983/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND ( type:  BatchToSpaceND )
# 984/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 985/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise/Relu6 ( type:  Relu6 )
# 986/1034: Analysing op name: MobilenetV2/expanded_conv_16/depthwise_output ( type:  Identity )
# 987/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/Conv2D ( type:  Conv2D )
# 988/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 989/1034: Analysing op name: MobilenetV2/expanded_conv_16/project/Identity ( type:  Identity )
# 990/1034: Analysing op name: MobilenetV2/expanded_conv_16/output ( type:  Identity )
# 991/1034: Analysing op name: aspp0/Conv2D ( type:  Conv2D )
# 992/1034: Analysing op name: aspp0/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 993/1034: Analysing op name: aspp0/Relu ( type:  Relu )
# 994/1034: Analysing op name: AvgPool2D/AvgPool ( type:  AvgPool )
# 995/1034: Analysing op name: image_pooling/Conv2D ( type:  Conv2D )
# 996/1034: Analysing op name: image_pooling/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 997/1034: Analysing op name: image_pooling/Relu ( type:  Relu )
# 998/1034: Analysing op name: ResizeBilinear ( type:  ResizeBilinear )
# 999/1034: Analysing op name: concat ( type:  ConcatV2 )
# 1000/1034: Analysing op name: concat_projection/Conv2D ( type:  Conv2D )
# 1001/1034: Analysing op name: concat_projection/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1002/1034: Analysing op name: concat_projection/Relu ( type:  Relu )
# 1003/1034: Analysing op name: concat_projection_dropout/Identity ( type:  Identity )
# 1004/1034: Analysing op name: decoder/ResizeBilinear ( type:  ResizeBilinear )
# 1005/1034: Analysing op name: decoder/concat ( type:  ConcatV2 )
# 1006/1034: Analysing op name: decoder/decoder_conv0_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1007/1034: Analysing op name: decoder/decoder_conv0_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1008/1034: Analysing op name: decoder/decoder_conv0_depthwise/Relu ( type:  Relu )
# 1009/1034: Analysing op name: decoder/decoder_conv0_pointwise/Conv2D ( type:  Conv2D )
# 1010/1034: Analysing op name: decoder/decoder_conv0_pointwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1011/1034: Analysing op name: decoder/decoder_conv0_pointwise/Relu ( type:  Relu )
# 1012/1034: Analysing op name: decoder/decoder_conv1_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1013/1034: Analysing op name: decoder/decoder_conv1_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1014/1034: Analysing op name: decoder/decoder_conv1_depthwise/Relu ( type:  Relu )
# 1015/1034: Analysing op name: decoder/decoder_conv1_pointwise/Conv2D ( type:  Conv2D )
# 1016/1034: Analysing op name: decoder/decoder_conv1_pointwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1017/1034: Analysing op name: decoder/decoder_conv1_pointwise/Relu ( type:  Relu )
# 1018/1034: Analysing op name: logits/semantic/Conv2D ( type:  Conv2D )
# 1019/1034: Analysing op name: logits/semantic/BiasAdd ( type:  BiasAdd )
# 1020/1034: Analysing op name: ResizeBilinear_1 ( type:  ResizeBilinear )
# 1021/1034: Analysing op name: ResizeBilinear_2 ( type:  ResizeBilinear )
# 1022/1034: Analysing op name: ArgMax ( type:  ArgMax )
# 1023/1034: Analysing op name: Slice ( type:  Slice )
# Translation to CoreML spec completed. Now compiling and saving the CoreML model.
#
#  Core ML model generated. Saved at location: DeepLabV3_no_metadata.mlmodel
#
# Core ML input(s):
#  [name: "ImageTensor__0"
# type {
#   imageType {
#     width: 513
#     height: 513
#     colorSpace: RGB
#   }
# }
# ]
# Core ML output(s):
#  [name: "ArgMax__0"
# type {
#   multiArrayType {
#     dataType: DOUBLE
#   }
# }
# ]

# %%
from coremltools.models.neural_network import quantization_utils

# allowed values of nbits = 16, 8, 7, 6, ...., 1
spec = quantization_utils.quantize_weights(coreml_model, nbits=8)
# Out:
# Quantizing using linear quantization
# Optimizing Neural Network before Quantization:
# Fused MobilenetV2/Conv/Conv2D:0->MobilenetV2/Conv/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv/depthwise/depthwise:0->MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv/project/Conv2D:0->MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_1/expand/Conv2D:0->MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_1/depthwise/depthwise:0->MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_1/project/Conv2D:0->MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_2/expand/Conv2D:0->MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_2/depthwise/depthwise:0->MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm:0
# Fused decoder/feature_projection0/Conv2D:0->decoder/feature_projection0/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_2/project/Conv2D:0->MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_3/expand/Conv2D:0->MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_3/depthwise/depthwise:0->MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_3/project/Conv2D:0->MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_4/expand/Conv2D:0->MobilenetV2/expanded_conv_4/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_4/depthwise/depthwise:0->MobilenetV2/expanded_conv_4/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_4/project/Conv2D:0->MobilenetV2/expanded_conv_4/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_5/expand/Conv2D:0->MobilenetV2/expanded_conv_5/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_5/depthwise/depthwise:0->MobilenetV2/expanded_conv_5/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_5/project/Conv2D:0->MobilenetV2/expanded_conv_5/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_6/expand/Conv2D:0->MobilenetV2/expanded_conv_6/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_6/depthwise/depthwise:0->MobilenetV2/expanded_conv_6/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_6/project/Conv2D:0->MobilenetV2/expanded_conv_6/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_7/expand/Conv2D:0->MobilenetV2/expanded_conv_7/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_7/depthwise/depthwise:0->MobilenetV2/expanded_conv_7/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_7/project/Conv2D:0->MobilenetV2/expanded_conv_7/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_8/expand/Conv2D:0->MobilenetV2/expanded_conv_8/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_8/depthwise/depthwise:0->MobilenetV2/expanded_conv_8/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_8/project/Conv2D:0->MobilenetV2/expanded_conv_8/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_9/expand/Conv2D:0->MobilenetV2/expanded_conv_9/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_9/depthwise/depthwise:0->MobilenetV2/expanded_conv_9/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_9/project/Conv2D:0->MobilenetV2/expanded_conv_9/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_10/expand/Conv2D:0->MobilenetV2/expanded_conv_10/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_10/depthwise/depthwise:0->MobilenetV2/expanded_conv_10/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_10/project/Conv2D:0->MobilenetV2/expanded_conv_10/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_11/expand/Conv2D:0->MobilenetV2/expanded_conv_11/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_11/depthwise/depthwise:0->MobilenetV2/expanded_conv_11/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_11/project/Conv2D:0->MobilenetV2/expanded_conv_11/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_12/expand/Conv2D:0->MobilenetV2/expanded_conv_12/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_12/depthwise/depthwise:0->MobilenetV2/expanded_conv_12/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_12/project/Conv2D:0->MobilenetV2/expanded_conv_12/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_13/expand/Conv2D:0->MobilenetV2/expanded_conv_13/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_13/depthwise/depthwise:0->MobilenetV2/expanded_conv_13/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_13/project/Conv2D:0->MobilenetV2/expanded_conv_13/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_14/expand/Conv2D:0->MobilenetV2/expanded_conv_14/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_14/depthwise/depthwise:0->MobilenetV2/expanded_conv_14/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_14/project/Conv2D:0->MobilenetV2/expanded_conv_14/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_15/expand/Conv2D:0->MobilenetV2/expanded_conv_15/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_15/depthwise/depthwise:0->MobilenetV2/expanded_conv_15/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_15/project/Conv2D:0->MobilenetV2/expanded_conv_15/project/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_16/expand/Conv2D:0->MobilenetV2/expanded_conv_16/expand/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_16/depthwise/depthwise:0->MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm:0
# Fused MobilenetV2/expanded_conv_16/project/Conv2D:0->MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm:0
# Fused aspp0/Conv2D:0->aspp0/BatchNorm/FusedBatchNorm:0
# Fused image_pooling/Conv2D:0->image_pooling/BatchNorm/FusedBatchNorm:0
# Fused concat_projection/Conv2D:0->concat_projection/BatchNorm/FusedBatchNorm:0
# Fused decoder/decoder_conv0_depthwise/depthwise:0->decoder/decoder_conv0_depthwise/BatchNorm/FusedBatchNorm:0
# Fused decoder/decoder_conv0_pointwise/Conv2D:0->decoder/decoder_conv0_pointwise/BatchNorm/FusedBatchNorm:0
# Fused decoder/decoder_conv1_depthwise/depthwise:0->decoder/decoder_conv1_depthwise/BatchNorm/FusedBatchNorm:0
# Fused decoder/decoder_conv1_pointwise/Conv2D:0->decoder/decoder_conv1_pointwise/BatchNorm/FusedBatchNorm:0
# Fused logits/semantic/Conv2D:0->logits/semantic/BiasAdd:0
# Finished optimizing network. Quantizing neural network..
# Quantizing layer Reshape/tensor:0
# Quantizing layer negated_Reshape:0_sub_2:0
# Quantizing layer MobilenetV2/Conv/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_1/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_1/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_1/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_2/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_2/depthwise/depthwise:0
# Quantizing layer decoder/feature_projection0/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_2/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_3/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_3/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_3/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_4/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_4/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_4/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_5/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_5/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_5/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_6/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_6/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_6/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_7/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_7/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_7/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_8/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_8/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_8/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_9/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_9/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_9/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_10/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_10/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_10/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_11/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_11/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_11/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_12/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_12/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_12/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_13/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_13/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_13/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_14/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_14/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_14/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_15/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_15/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_15/project/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_16/expand/Conv2D:0
# Quantizing layer MobilenetV2/expanded_conv_16/depthwise/depthwise:0
# Quantizing layer MobilenetV2/expanded_conv_16/project/Conv2D:0
# Quantizing layer aspp0/Conv2D:0
# Quantizing layer image_pooling/Conv2D:0
# Quantizing layer concat_projection/Conv2D:0
# Quantizing layer decoder/decoder_conv0_depthwise/depthwise:0
# Quantizing layer decoder/decoder_conv0_pointwise/Conv2D:0
# Quantizing layer decoder/decoder_conv1_depthwise/depthwise:0
# Quantizing layer decoder/decoder_conv1_pointwise/Conv2D:0
# Quantizing layer logits/semantic/Conv2D:0
# WARNING! Unable to return a quantized MLModel instance sinceOS != macOS 10.14 or later
# Returning quantized model specification instead

# %%
# Fill in the descriptions and metadata.
spec.description.metadata.versionString = "2021-08-11"
spec.description.metadata.shortDescription = "deeplabv3_mnv2_ade20k_train_2018_12_03"
spec.description.metadata.author = "Converted by Anh"


# Rename inputs and outputs.
old_input_name = "ImageTensor__0"
new_input_name = "image"

old_output_name = "ArgMax__0"
new_output_name = "scores"

ct.utils.rename_feature(spec, old_input_name, new_input_name)
ct.utils.rename_feature(spec, old_output_name, new_output_name)

spec.description.input[0].shortDescription = "Input image"
spec.description.output[0].shortDescription = "Segmentation map"

# Fix up the output shape and make it INT32.
spec.description.output[0].type.multiArrayType.shape.append(513)
spec.description.output[0].type.multiArrayType.shape.append(513)
spec.description.output[0].type.multiArrayType.dataType = ct.proto.FeatureTypes_pb2.ArrayFeatureType.INT32

# %%
print(spec.description)
# Out:
# input {
#   name: "image"
#   shortDescription: "Input image"
#   type {
#     imageType {
#       width: 513
#       height: 513
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "scores"
#   shortDescription: "Segmentation map"
#   type {
#     multiArrayType {
#       shape: 513
#       shape: 513
#       dataType: INT32
#     }
#   }
# }
# metadata {
#   shortDescription: "deeplabv3_mnv2_ade20k_train_2018_12_03"
#   versionString: "2021-08-11"
#   author: "Converted by Anh"
# }

# %%
labels = """
wall
building, edifice
sky
floor, flooring
tree
ceiling
road, route
bed 
windowpane, window 
grass
cabinet
sidewalk, pavement
person, individual, someone, somebody, mortal, soul
earth, ground
door, double door
table
mountain, mount
plant, flora, plant life
curtain, drape, drapery, mantle, pall
chair
car, auto, automobile, machine, motorcar
water
painting, picture
sofa, couch, lounge
shelf
house
sea
mirror
rug, carpet, carpeting
field
armchair
seat
fence, fencing
desk
rock, stone
wardrobe, closet, press
lamp
bathtub, bathing tub, bath, tub
railing, rail
cushion
base, pedestal, stand
box
column, pillar
signboard, sign
chest of drawers, chest, bureau, dresser
counter
sand
sink
skyscraper
fireplace, hearth, open fireplace
refrigerator, icebox
grandstand, covered stand
path
stairs, steps
runway
case, display case, showcase, vitrine
pool table, billiard table, snooker table
pillow
screen door, screen
stairway, staircase
river
bridge, span
bookcase
blind, screen
coffee table, cocktail table
toilet, can, commode, crapper, pot, potty, stool, throne
flower
book
hill
bench
countertop
stove, kitchen stove, range, kitchen range, cooking stove
palm, palm tree
kitchen island
computer, computing machine, computing device, data processor, electronic computer, information processing system
swivel chair
boat
bar
arcade machine
hovel, hut, hutch, shack, shanty
bus, autobus, coach, charabanc, double-decker, jitney, motorbus, motorcoach, omnibus, passenger vehicle
towel
light, light source
truck, motortruck
tower
chandelier, pendant, pendent
awning, sunshade, sunblind
streetlight, street lamp
booth, cubicle, stall, kiosk
television, television receiver, television set, tv, tv set, idiot box, boob tube, telly, goggle box
airplane, aeroplane, plane
dirt track
apparel, wearing apparel, dress, clothes
pole
land, ground, soil
bannister, banister, balustrade, balusters, handrail
escalator, moving staircase, moving stairway
ottoman, pouf, pouffe, puff, hassock
bottle
buffet, counter, sideboard
poster, posting, placard, notice, bill, card
stage
van
ship
fountain
conveyer belt, conveyor belt, conveyer, conveyor, transporter
canopy
washer, automatic washer, washing machine
plaything, toy
swimming pool, swimming bath, natatorium
stool
barrel, cask
basket, handbasket
waterfall, falls
tent, collapsible shelter
bag
minibike, motorbike
cradle
oven
ball
food, solid food
step, stair
tank, storage tank
trade name, brand name, brand, marque
microwave, microwave oven
pot, flowerpot
animal, animate being, beast, brute, creature, fauna
bicycle, bike, wheel, cycle 
lake
dishwasher, dish washer, dishwashing machine
screen, silver screen, projection screen
blanket, cover
sculpture
hood, exhaust hood
sconce
vase
traffic light, traffic signal, stoplight
tray
ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin
fan
pier, wharf, wharfage, dock
crt screen
plate
monitor, monitoring device
bulletin board, notice board
shower
radiator
glass, drinking glass
clock
flag
"""
 
labels_list = labels.split('\n')
print(len(labels_list))
print(labels_list)
assert(len(labels_list) == 152)
# Out:
# 152
# ['', 'wall', 'building, edifice', 'sky', 'floor, flooring', 'tree', 'ceiling', 'road, route', 'bed ', 'windowpane, window ', 'grass', 'cabinet', 'sidewalk, pavement', 'person, individual, someone, somebody, mortal, soul', 'earth, ground', 'door, double door', 'table', 'mountain, mount', 'plant, flora, plant life', 'curtain, drape, drapery, mantle, pall', 'chair', 'car, auto, automobile, machine, motorcar', 'water', 'painting, picture', 'sofa, couch, lounge', 'shelf', 'house', 'sea', 'mirror', 'rug, carpet, carpeting', 'field', 'armchair', 'seat', 'fence, fencing', 'desk', 'rock, stone', 'wardrobe, closet, press', 'lamp', 'bathtub, bathing tub, bath, tub', 'railing, rail', 'cushion', 'base, pedestal, stand', 'box', 'column, pillar', 'signboard, sign', 'chest of drawers, chest, bureau, dresser', 'counter', 'sand', 'sink', 'skyscraper', 'fireplace, hearth, open fireplace', 'refrigerator, icebox', 'grandstand, covered stand', 'path', 'stairs, steps', 'runway', 'case, display case, showcase, vitrine', 'pool table, billiard table, snooker table', 'pillow', 'screen door, screen', 'stairway, staircase', 'river', 'bridge, span', 'bookcase', 'blind, screen', 'coffee table, cocktail table', 'toilet, can, commode, crapper, pot, potty, stool, throne', 'flower', 'book', 'hill', 'bench', 'countertop', 'stove, kitchen stove, range, kitchen range, cooking stove', 'palm, palm tree', 'kitchen island', 'computer, computing machine, computing device, data processor, electronic computer, information processing system', 'swivel chair', 'boat', 'bar', 'arcade machine', 'hovel, hut, hutch, shack, shanty', 'bus, autobus, coach, charabanc, double-decker, jitney, motorbus, motorcoach, omnibus, passenger vehicle', 'towel', 'light, light source', 'truck, motortruck', 'tower', 'chandelier, pendant, pendent', 'awning, sunshade, sunblind', 'streetlight, street lamp', 'booth, cubicle, stall, kiosk', 'television, television receiver, television set, tv, tv set, idiot box, boob tube, telly, goggle box', 'airplane, aeroplane, plane', 'dirt track', 'apparel, wearing apparel, dress, clothes', 'pole', 'land, ground, soil', 'bannister, banister, balustrade, balusters, handrail', 'escalator, moving staircase, moving stairway', 'ottoman, pouf, pouffe, puff, hassock', 'bottle', 'buffet, counter, sideboard', 'poster, posting, placard, notice, bill, card', 'stage', 'van', 'ship', 'fountain', 'conveyer belt, conveyor belt, conveyer, conveyor, transporter', 'canopy', 'washer, automatic washer, washing machine', 'plaything, toy', 'swimming pool, swimming bath, natatorium', 'stool', 'barrel, cask', 'basket, handbasket', 'waterfall, falls', 'tent, collapsible shelter', 'bag', 'minibike, motorbike', 'cradle', 'oven', 'ball', 'food, solid food', 'step, stair', 'tank, storage tank', 'trade name, brand name, brand, marque', 'microwave, microwave oven', 'pot, flowerpot', 'animal, animate being, beast, brute, creature, fauna', 'bicycle, bike, wheel, cycle ', 'lake', 'dishwasher, dish washer, dishwashing machine', 'screen, silver screen, projection screen', 'blanket, cover', 'sculpture', 'hood, exhaust hood', 'sconce', 'vase', 'traffic light, traffic signal, stoplight', 'tray', 'ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', 'fan', 'pier, wharf, wharfage, dock', 'crt screen', 'plate', 'monitor, monitoring device', 'bulletin board, notice board', 'shower', 'radiator', 'glass, drinking glass', 'clock', 'flag', '']

# %%
import json
from numpy import loadtxt

labels_json = {"labels": labels_list}

# load the model
mlmodel = ct.models.MLModel(spec)
mlmodel.user_defined_metadata["com.apple.coreml.model.preview.type"] = "imageSegmenter"
mlmodel.user_defined_metadata['com.apple.coreml.model.preview.params'] = json.dumps(labels_json)

mlmodel.save("DeepLabV3_ADE20K.mlmodel")
print(mlmodel)
# Out:
# input {
#   name: "image"
#   shortDescription: "Input image"
#   type {
#     imageType {
#       width: 513
#       height: 513
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "scores"
#   shortDescription: "Segmentation map"
#   type {
#     multiArrayType {
#       shape: 513
#       shape: 513
#       dataType: INT32
#     }
#   }
# }
# metadata {
#   shortDescription: "deeplabv3_mnv2_ade20k_train_2018_12_03"
#   versionString: "2021-08-11"
#   author: "Converted by Anh"
#   userDefined {
#     key: "com.apple.coreml.model.preview.params"
#     value: "{\"labels\": [\"\", \"wall\", \"building, edifice\", \"sky\", \"floor, flooring\", \"tree\", \"ceiling\", \"road, route\", \"bed \", \"windowpane, window \", \"grass\", \"cabinet\", \"sidewalk, pavement\", \"person, individual, someone, somebody, mortal, soul\", \"earth, ground\", \"door, double door\", \"table\", \"mountain, mount\", \"plant, flora, plant life\", \"curtain, drape, drapery, mantle, pall\", \"chair\", \"car, auto, automobile, machine, motorcar\", \"water\", \"painting, picture\", \"sofa, couch, lounge\", \"shelf\", \"house\", \"sea\", \"mirror\", \"rug, carpet, carpeting\", \"field\", \"armchair\", \"seat\", \"fence, fencing\", \"desk\", \"rock, stone\", \"wardrobe, closet, press\", \"lamp\", \"bathtub, bathing tub, bath, tub\", \"railing, rail\", \"cushion\", \"base, pedestal, stand\", \"box\", \"column, pillar\", \"signboard, sign\", \"chest of drawers, chest, bureau, dresser\", \"counter\", \"sand\", \"sink\", \"skyscraper\", \"fireplace, hearth, open fireplace\", \"refrigerator, icebox\", \"grandstand, covered stand\", \"path\", \"stairs, steps\", \"runway\", \"case, display case, showcase, vitrine\", \"pool table, billiard table, snooker table\", \"pillow\", \"screen door, screen\", \"stairway, staircase\", \"river\", \"bridge, span\", \"bookcase\", \"blind, screen\", \"coffee table, cocktail table\", \"toilet, can, commode, crapper, pot, potty, stool, throne\", \"flower\", \"book\", \"hill\", \"bench\", \"countertop\", \"stove, kitchen stove, range, kitchen range, cooking stove\", \"palm, palm tree\", \"kitchen island\", \"computer, computing machine, computing device, data processor, electronic computer, information processing system\", \"swivel chair\", \"boat\", \"bar\", \"arcade machine\", \"hovel, hut, hutch, shack, shanty\", \"bus, autobus, coach, charabanc, double-decker, jitney, motorbus, motorcoach, omnibus, passenger vehicle\", \"towel\", \"light, light source\", \"truck, motortruck\", \"tower\", \"chandelier, pendant, pendent\", \"awning, sunshade, sunblind\", \"streetlight, street lamp\", \"booth, cubicle, stall, kiosk\", \"television, television receiver, television set, tv, tv set, idiot box, boob tube, telly, goggle box\", \"airplane, aeroplane, plane\", \"dirt track\", \"apparel, wearing apparel, dress, clothes\", \"pole\", \"land, ground, soil\", \"bannister, banister, balustrade, balusters, handrail\", \"escalator, moving staircase, moving stairway\", \"ottoman, pouf, pouffe, puff, hassock\", \"bottle\", \"buffet, counter, sideboard\", \"poster, posting, placard, notice, bill, card\", \"stage\", \"van\", \"ship\", \"fountain\", \"conveyer belt, conveyor belt, conveyer, conveyor, transporter\", \"canopy\", \"washer, automatic washer, washing machine\", \"plaything, toy\", \"swimming pool, swimming bath, natatorium\", \"stool\", \"barrel, cask\", \"basket, handbasket\", \"waterfall, falls\", \"tent, collapsible shelter\", \"bag\", \"minibike, motorbike\", \"cradle\", \"oven\", \"ball\", \"food, solid food\", \"step, stair\", \"tank, storage tank\", \"trade name, brand name, brand, marque\", \"microwave, microwave oven\", \"pot, flowerpot\", \"animal, animate being, beast, brute, creature, fauna\", \"bicycle, bike, wheel, cycle \", \"lake\", \"dishwasher, dish washer, dishwashing machine\", \"screen, silver screen, projection screen\", \"blanket, cover\", \"sculpture\", \"hood, exhaust hood\", \"sconce\", \"vase\", \"traffic light, traffic signal, stoplight\", \"tray\", \"ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin\", \"fan\", \"pier, wharf, wharfage, dock\", \"crt screen\", \"plate\", \"monitor, monitoring device\", \"bulletin board, notice board\", \"shower\", \"radiator\", \"glass, drinking glass\", \"clock\", \"flag\", \"\"]}"
#   }
#   userDefined {
#     key: "com.apple.coreml.model.preview.type"
#     value: "imageSegmenter"
#   }
# }
