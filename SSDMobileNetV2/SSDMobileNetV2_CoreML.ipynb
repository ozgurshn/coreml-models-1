# %% [markdown]
# # About
#
# Convert ssd_mobilenet_v2_coco_2018_03_29 to Core ML
#
# The code is based on this: https://github.com/hollance/coreml-survival-guide/blob/master/MobileNetV2%2BSSDLite/ssdlite.py

# %% [markdown]
# # Download model and setup environment

# %%
# !wget http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_coco_2018_03_29.tar.gz
# !tar -zxvf ssd_mobilenet_v2_coco_2018_03_29.tar.gz
# !wget https://raw.githubusercontent.com/hollance/coreml-survival-guide/master/MobileNetV2%2BSSDLite/coco_labels.txt
# Out:
# --2021-08-07 13:30:30--  http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_coco_2018_03_29.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.152.128, 2607:f8b0:4001:c56::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.152.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 187925923 (179M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_coco_2018_03_29.tar.gz.2’
#
# ssd_mobilenet_v2_co 100%[===================>] 179.22M   227MB/s    in 0.8s
#
# 2021-08-07 13:30:31 (227 MB/s) - ‘ssd_mobilenet_v2_coco_2018_03_29.tar.gz.2’ saved [187925923/187925923]
#
# ssd_mobilenet_v2_coco_2018_03_29/checkpoint
# ssd_mobilenet_v2_coco_2018_03_29/model.ckpt.meta
# ssd_mobilenet_v2_coco_2018_03_29/pipeline.config
# ssd_mobilenet_v2_coco_2018_03_29/saved_model/saved_model.pb
# ssd_mobilenet_v2_coco_2018_03_29/frozen_inference_graph.pb
# ssd_mobilenet_v2_coco_2018_03_29/saved_model/
# ssd_mobilenet_v2_coco_2018_03_29/saved_model/variables/
# ssd_mobilenet_v2_coco_2018_03_29/model.ckpt.index
# ssd_mobilenet_v2_coco_2018_03_29/
# ssd_mobilenet_v2_coco_2018_03_29/model.ckpt.data-00000-of-00001
# --2021-08-07 13:30:34--  https://raw.githubusercontent.com/hollance/coreml-survival-guide/master/MobileNetV2%2BSSDLite/coco_labels.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 641 [text/plain]
# Saving to: ‘coco_labels.txt.1’
#
# coco_labels.txt.1   100%[===================>]     641  --.-KB/s    in 0s
#
# 2021-08-07 13:30:34 (43.5 MB/s) - ‘coco_labels.txt.1’ saved [641/641]

# %%
# !pip install coremltools==4.1
# !pip install tfcoreml==2.0.0
# Out:
# Requirement already satisfied: coremltools==4.1 in /usr/local/lib/python3.7/dist-packages (4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (4.41.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (21.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (21.0)
# Requirement already satisfied: numpy<1.20,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.4.1)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (3.17.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (1.15.0)
# Requirement already satisfied: attr in /usr/local/lib/python3.7/dist-packages (from coremltools==4.1) (0.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->coremltools==4.1) (2.4.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->coremltools==4.1) (1.2.1)
# Requirement already satisfied: tfcoreml==2.0.0 in /usr/local/lib/python3.7/dist-packages (2.0)
# Requirement already satisfied: tensorflow<=1.14,>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (1.14.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (1.15.0)
# Requirement already satisfied: numpy>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (1.19.5)
# Requirement already satisfied: coremltools>=0.8 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (4.1)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tfcoreml==2.0.0) (3.17.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (21.2.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (1.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (21.0)
# Requirement already satisfied: attr in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (0.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from coremltools>=0.8->tfcoreml==2.0.0) (4.41.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.12.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.36.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.34.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.12.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.14.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.14.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.8.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (0.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (57.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (4.6.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (1.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow<=1.14,>=1.5.0->tfcoreml==2.0.0) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->coremltools>=0.8->tfcoreml==2.0.0) (2.4.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->coremltools>=0.8->tfcoreml==2.0.0) (1.2.1)

# %%
import sys
print(sys.version)

import tensorflow as tf
print(tf.__version__)

import coremltools as ct
print(ct.__version__)
# Out:
# 3.7.11 (default, Jul  3 2021, 18:01:19)
# [GCC 7.5.0]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0
# WARNING:root:scikit-learn version 0.22.2.post1 is not supported. Minimum required version: 0.17. Maximum required version: 0.19.2. Disabling scikit-learn conversion API.
# 4.1

# %% [markdown]
# # Convert to Core ML

# %%
import numpy as np

import tensorflow as tf
from tensorflow.python.tools import strip_unused_lib
from tensorflow.python.framework import dtypes
from tensorflow.python.platform import gfile

import tfcoreml
import coremltools as ct


# From where to load the saved_model.pb file.
saved_model_path = "ssd_mobilenet_v2_coco_2018_03_29/saved_model"

# Where to save the final Core ML model file.
coreml_model_path = "SSDMobileNetV2.mlmodel"

# The number of predicted classes, excluding background.
num_classes = 90

# The number of predicted bounding boxes.
num_anchors = 1917

# Size of the expected input image.
input_width = 300
input_height = 300


# =============================
# PART 1: MobileNetV2 + SSD
# =============================

# Temporary file. You can delete this after the conversion is done.
frozen_model_file = "frozen_model.pb"

# Names of the interesting tensors in the graph. We use "Postprocessor/convert_scores"
# instead of "concat_1" because this already applies the sigmoid to the class scores.
input_node = "Preprocessor/sub"
bbox_output_node = "concat"
class_output_node = "Postprocessor/convert_scores"

input_tensor = input_node + ":0"
bbox_output_tensor = bbox_output_node + ":0"
class_output_tensor = class_output_node + ":0"


def load_saved_model(path):
    """Loads a saved model into a graph."""
    print("Loading saved_model.pb from '%s'" % path)
    the_graph = tf.Graph()
    with tf.Session(graph=the_graph) as sess:
        tf.saved_model.loader.load(sess, [tf.saved_model.tag_constants.SERVING], path)
    return the_graph


def optimize_graph(graph):
    """Strips unused subgraphs and save it as another frozen TF model."""
    gdef = strip_unused_lib.strip_unused(
            input_graph_def = graph.as_graph_def(),
            input_node_names = [input_node],
            output_node_names = [bbox_output_node, class_output_node],
            placeholder_type_enum = dtypes.float32.as_datatype_enum)

    with gfile.GFile(frozen_model_file, "wb") as f:
        f.write(gdef.SerializeToString())


# Load the original graph and remove anything we don't need.
the_graph = load_saved_model(saved_model_path)
optimize_graph(the_graph)
# Out:
# Loading saved_model.pb from 'ssd_mobilenet_v2_coco_2018_03_29/saved_model'

# %%
# Convert to Core ML model.
ssd_model = tfcoreml.convert(
    tf_model_path=frozen_model_file,
    mlmodel_path=coreml_model_path,
    input_name_shape_dict={ input_tensor: [1, input_height, input_width, 3] },
    image_input_names=input_tensor,
    output_feature_names=[bbox_output_tensor, class_output_tensor],
    is_bgr=False,
    red_bias=-1.0,
    green_bias=-1.0,
    blue_bias=-1.0,
    image_scale=2./255)

spec = ssd_model.get_spec()

# Rename the inputs and outputs to something more readable.
spec.description.input[0].name = "image"
spec.description.input[0].shortDescription = "Input image"
spec.description.output[0].name = "scores"
spec.description.output[0].shortDescription = "Predicted class scores for each bounding box"
spec.description.output[1].name = "boxes"
spec.description.output[1].shortDescription = "Predicted coordinates for each bounding box"

input_mlmodel = input_tensor.replace(":", "__").replace("/", "__")
class_output_mlmodel = class_output_tensor.replace(":", "__").replace("/", "__")
bbox_output_mlmodel = bbox_output_tensor.replace(":", "__").replace("/", "__")

for i in range(len(spec.neuralNetwork.layers)):
    if spec.neuralNetwork.layers[i].input[0] == input_mlmodel:
        spec.neuralNetwork.layers[i].input[0] = "image"
    if spec.neuralNetwork.layers[i].output[0] == class_output_mlmodel:
        spec.neuralNetwork.layers[i].output[0] = "scores"
    if spec.neuralNetwork.layers[i].output[0] == bbox_output_mlmodel:
        spec.neuralNetwork.layers[i].output[0] = "boxes"

spec.neuralNetwork.preprocessing[0].featureName = "image"

# For some reason the output shape of the "scores" output is not filled in.
spec.description.output[0].type.multiArrayType.shape.append(num_classes + 1)
spec.description.output[0].type.multiArrayType.shape.append(num_anchors)

# And the "boxes" output shape is (4, 1917, 1) so get rid of that last one.
del spec.description.output[1].type.multiArrayType.shape[-1]

# Convert weights to 16-bit floats to make the model smaller.
spec = ct.utils.convert_neural_network_spec_weights_to_fp16(spec)

# Create a new MLModel from the modified spec and save it.
ssd_model = ct.models.MLModel(spec)
ssd_model.save('SSD.mlmodel')

print(ssd_model)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# Collecting all the 'Const' ops from the graph, by running it....
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob Preprocessor/sub:0
# 1/1522: Analysing op name: Postprocessor/scale_logits/y ( type:  Const )
# 2/1522: Analysing op name: concat_1/axis ( type:  Const )
# 3/1522: Analysing op name: concat/axis ( type:  Const )
# 4/1522: Analysing op name: BoxPredictor_5/stack_1/2 ( type:  Const )
# 5/1522: Analysing op name: BoxPredictor_5/stack_1/1 ( type:  Const )
# 6/1522: Analysing op name: BoxPredictor_5/stack/3 ( type:  Const )
# 7/1522: Analysing op name: BoxPredictor_5/stack/2 ( type:  Const )
# 8/1522: Analysing op name: BoxPredictor_5/stack/1 ( type:  Const )
# 9/1522: Analysing op name: BoxPredictor_5/strided_slice/stack_2 ( type:  Const )
# 10/1522: Analysing op name: BoxPredictor_5/strided_slice/stack_1 ( type:  Const )
# 11/1522: Analysing op name: BoxPredictor_5/strided_slice/stack ( type:  Const )
# 12/1522: Analysing op name: BoxPredictor_5/ClassPredictor/biases ( type:  Const )
# 13/1522: Analysing op name: BoxPredictor_5/ClassPredictor/biases/read ( type:  Identity )
# 14/1522: Analysing op name: BoxPredictor_5/ClassPredictor/weights ( type:  Const )
# 15/1522: Analysing op name: BoxPredictor_5/ClassPredictor/weights/read ( type:  Identity )
# 16/1522: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/biases ( type:  Const )
# 17/1522: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/biases/read ( type:  Identity )
# 18/1522: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/weights ( type:  Const )
# 19/1522: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/weights/read ( type:  Identity )
# 20/1522: Analysing op name: BoxPredictor_4/stack_1/2 ( type:  Const )
# 21/1522: Analysing op name: BoxPredictor_4/stack_1/1 ( type:  Const )
# 22/1522: Analysing op name: BoxPredictor_4/stack/3 ( type:  Const )
# 23/1522: Analysing op name: BoxPredictor_4/stack/2 ( type:  Const )
# 24/1522: Analysing op name: BoxPredictor_4/stack/1 ( type:  Const )
# 25/1522: Analysing op name: BoxPredictor_4/strided_slice/stack_2 ( type:  Const )
# 26/1522: Analysing op name: BoxPredictor_4/strided_slice/stack_1 ( type:  Const )
# 27/1522: Analysing op name: BoxPredictor_4/strided_slice/stack ( type:  Const )
# 28/1522: Analysing op name: BoxPredictor_4/ClassPredictor/biases ( type:  Const )
# 29/1522: Analysing op name: BoxPredictor_4/ClassPredictor/biases/read ( type:  Identity )
# 30/1522: Analysing op name: BoxPredictor_4/ClassPredictor/weights ( type:  Const )
# 31/1522: Analysing op name: BoxPredictor_4/ClassPredictor/weights/read ( type:  Identity )
# 32/1522: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/biases ( type:  Const )
# 33/1522: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/biases/read ( type:  Identity )
# 34/1522: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/weights ( type:  Const )
# 35/1522: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/weights/read ( type:  Identity )
# 36/1522: Analysing op name: BoxPredictor_3/stack_1/2 ( type:  Const )
# 37/1522: Analysing op name: BoxPredictor_3/stack_1/1 ( type:  Const )
# 38/1522: Analysing op name: BoxPredictor_3/stack/3 ( type:  Const )
# 39/1522: Analysing op name: BoxPredictor_3/stack/2 ( type:  Const )
# 40/1522: Analysing op name: BoxPredictor_3/stack/1 ( type:  Const )
# 41/1522: Analysing op name: BoxPredictor_3/strided_slice/stack_2 ( type:  Const )
# 42/1522: Analysing op name: BoxPredictor_3/strided_slice/stack_1 ( type:  Const )
# 43/1522: Analysing op name: BoxPredictor_3/strided_slice/stack ( type:  Const )
# 44/1522: Analysing op name: BoxPredictor_3/ClassPredictor/biases ( type:  Const )
# 45/1522: Analysing op name: BoxPredictor_3/ClassPredictor/biases/read ( type:  Identity )
# 46/1522: Analysing op name: BoxPredictor_3/ClassPredictor/weights ( type:  Const )
# 47/1522: Analysing op name: BoxPredictor_3/ClassPredictor/weights/read ( type:  Identity )
# 48/1522: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/biases ( type:  Const )
# 49/1522: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/biases/read ( type:  Identity )
# 50/1522: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/weights ( type:  Const )
# 51/1522: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/weights/read ( type:  Identity )
# 52/1522: Analysing op name: BoxPredictor_2/stack_1/2 ( type:  Const )
# 53/1522: Analysing op name: BoxPredictor_2/stack_1/1 ( type:  Const )
# 54/1522: Analysing op name: BoxPredictor_2/stack/3 ( type:  Const )
# 55/1522: Analysing op name: BoxPredictor_2/stack/2 ( type:  Const )
# 56/1522: Analysing op name: BoxPredictor_2/stack/1 ( type:  Const )
# 57/1522: Analysing op name: BoxPredictor_2/strided_slice/stack_2 ( type:  Const )
# 58/1522: Analysing op name: BoxPredictor_2/strided_slice/stack_1 ( type:  Const )
# 59/1522: Analysing op name: BoxPredictor_2/strided_slice/stack ( type:  Const )
# 60/1522: Analysing op name: BoxPredictor_2/ClassPredictor/biases ( type:  Const )
# 61/1522: Analysing op name: BoxPredictor_2/ClassPredictor/biases/read ( type:  Identity )
# 62/1522: Analysing op name: BoxPredictor_2/ClassPredictor/weights ( type:  Const )
# 63/1522: Analysing op name: BoxPredictor_2/ClassPredictor/weights/read ( type:  Identity )
# 64/1522: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/biases ( type:  Const )
# 65/1522: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/biases/read ( type:  Identity )
# 66/1522: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/weights ( type:  Const )
# 67/1522: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/weights/read ( type:  Identity )
# 68/1522: Analysing op name: BoxPredictor_1/stack_1/2 ( type:  Const )
# 69/1522: Analysing op name: BoxPredictor_1/stack_1/1 ( type:  Const )
# 70/1522: Analysing op name: BoxPredictor_1/stack/3 ( type:  Const )
# 71/1522: Analysing op name: BoxPredictor_1/stack/2 ( type:  Const )
# 72/1522: Analysing op name: BoxPredictor_1/stack/1 ( type:  Const )
# 73/1522: Analysing op name: BoxPredictor_1/strided_slice/stack_2 ( type:  Const )
# 74/1522: Analysing op name: BoxPredictor_1/strided_slice/stack_1 ( type:  Const )
# 75/1522: Analysing op name: BoxPredictor_1/strided_slice/stack ( type:  Const )
# 76/1522: Analysing op name: BoxPredictor_1/ClassPredictor/biases ( type:  Const )
# 77/1522: Analysing op name: BoxPredictor_1/ClassPredictor/biases/read ( type:  Identity )
# 78/1522: Analysing op name: BoxPredictor_1/ClassPredictor/weights ( type:  Const )
# 79/1522: Analysing op name: BoxPredictor_1/ClassPredictor/weights/read ( type:  Identity )
# 80/1522: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/biases ( type:  Const )
# 81/1522: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/biases/read ( type:  Identity )
# 82/1522: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/weights ( type:  Const )
# 83/1522: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/weights/read ( type:  Identity )
# 84/1522: Analysing op name: BoxPredictor_0/stack_1/2 ( type:  Const )
# 85/1522: Analysing op name: BoxPredictor_0/stack_1/1 ( type:  Const )
# 86/1522: Analysing op name: BoxPredictor_0/stack/3 ( type:  Const )
# 87/1522: Analysing op name: BoxPredictor_0/stack/2 ( type:  Const )
# 88/1522: Analysing op name: BoxPredictor_0/stack/1 ( type:  Const )
# 89/1522: Analysing op name: BoxPredictor_0/strided_slice/stack_2 ( type:  Const )
# 90/1522: Analysing op name: BoxPredictor_0/strided_slice/stack_1 ( type:  Const )
# 91/1522: Analysing op name: BoxPredictor_0/strided_slice/stack ( type:  Const )
# 92/1522: Analysing op name: BoxPredictor_0/ClassPredictor/biases ( type:  Const )
# 93/1522: Analysing op name: BoxPredictor_0/ClassPredictor/biases/read ( type:  Identity )
# 94/1522: Analysing op name: BoxPredictor_0/ClassPredictor/weights ( type:  Const )
# 95/1522: Analysing op name: BoxPredictor_0/ClassPredictor/weights/read ( type:  Identity )
# 96/1522: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/biases ( type:  Const )
# 97/1522: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/biases/read ( type:  Identity )
# 98/1522: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/weights ( type:  Const )
# 99/1522: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/weights/read ( type:  Identity )
# 100/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/add/y ( type:  Const )
# 101/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_variance ( type:  Const )
# 102/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_variance/read ( type:  Identity )
# 103/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/add ( type:  Add )
# 104/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 105/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_mean ( type:  Const )
# 106/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_mean/read ( type:  Identity )
# 107/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/beta ( type:  Const )
# 108/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/beta/read ( type:  Identity )
# 109/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/gamma ( type:  Const )
# 110/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/gamma/read ( type:  Identity )
# 111/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/mul ( type:  Mul )
# 112/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 113/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/sub ( type:  Sub )
# 114/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/weights ( type:  Const )
# 115/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/weights/read ( type:  Identity )
# 116/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/batchnorm/add/y ( type:  Const )
# 117/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_variance ( type:  Const )
# 118/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 119/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/batchnorm/add ( type:  Add )
# 120/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 121/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_mean ( type:  Const )
# 122/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 123/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/beta ( type:  Const )
# 124/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/beta/read ( type:  Identity )
# 125/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/gamma ( type:  Const )
# 126/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 127/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/batchnorm/mul ( type:  Mul )
# 128/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 129/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/batchnorm/sub ( type:  Sub )
# 130/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/depthwise_weights ( type:  Const )
# 131/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/depthwise_weights/read ( type:  Identity )
# 132/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/batchnorm/add/y ( type:  Const )
# 133/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_variance ( type:  Const )
# 134/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_variance/read ( type:  Identity )
# 135/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/batchnorm/add ( type:  Add )
# 136/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 137/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_mean ( type:  Const )
# 138/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_mean/read ( type:  Identity )
# 139/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/beta ( type:  Const )
# 140/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/beta/read ( type:  Identity )
# 141/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/gamma ( type:  Const )
# 142/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/gamma/read ( type:  Identity )
# 143/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/batchnorm/mul ( type:  Mul )
# 144/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 145/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/batchnorm/sub ( type:  Sub )
# 146/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/weights ( type:  Const )
# 147/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/weights/read ( type:  Identity )
# 148/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/batchnorm/add/y ( type:  Const )
# 149/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_variance ( type:  Const )
# 150/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_variance/read ( type:  Identity )
# 151/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/batchnorm/add ( type:  Add )
# 152/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 153/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_mean ( type:  Const )
# 154/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_mean/read ( type:  Identity )
# 155/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/beta ( type:  Const )
# 156/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/beta/read ( type:  Identity )
# 157/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/gamma ( type:  Const )
# 158/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/gamma/read ( type:  Identity )
# 159/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/batchnorm/mul ( type:  Mul )
# 160/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 161/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/batchnorm/sub ( type:  Sub )
# 162/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/weights ( type:  Const )
# 163/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/weights/read ( type:  Identity )
# 164/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/batchnorm/add/y ( type:  Const )
# 165/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_variance ( type:  Const )
# 166/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 167/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/batchnorm/add ( type:  Add )
# 168/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 169/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_mean ( type:  Const )
# 170/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 171/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/beta ( type:  Const )
# 172/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/beta/read ( type:  Identity )
# 173/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/gamma ( type:  Const )
# 174/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 175/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/batchnorm/mul ( type:  Mul )
# 176/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 177/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/batchnorm/sub ( type:  Sub )
# 178/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/depthwise_weights ( type:  Const )
# 179/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/depthwise_weights/read ( type:  Identity )
# 180/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/batchnorm/add/y ( type:  Const )
# 181/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_variance ( type:  Const )
# 182/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_variance/read ( type:  Identity )
# 183/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/batchnorm/add ( type:  Add )
# 184/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 185/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_mean ( type:  Const )
# 186/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_mean/read ( type:  Identity )
# 187/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/beta ( type:  Const )
# 188/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/beta/read ( type:  Identity )
# 189/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/gamma ( type:  Const )
# 190/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/gamma/read ( type:  Identity )
# 191/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/batchnorm/mul ( type:  Mul )
# 192/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 193/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/batchnorm/sub ( type:  Sub )
# 194/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/weights ( type:  Const )
# 195/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/weights/read ( type:  Identity )
# 196/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/batchnorm/add/y ( type:  Const )
# 197/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_variance ( type:  Const )
# 198/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_variance/read ( type:  Identity )
# 199/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/batchnorm/add ( type:  Add )
# 200/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 201/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_mean ( type:  Const )
# 202/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_mean/read ( type:  Identity )
# 203/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/beta ( type:  Const )
# 204/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/beta/read ( type:  Identity )
# 205/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/gamma ( type:  Const )
# 206/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/gamma/read ( type:  Identity )
# 207/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/batchnorm/mul ( type:  Mul )
# 208/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 209/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/batchnorm/sub ( type:  Sub )
# 210/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/weights ( type:  Const )
# 211/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/weights/read ( type:  Identity )
# 212/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/batchnorm/add/y ( type:  Const )
# 213/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_variance ( type:  Const )
# 214/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 215/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/batchnorm/add ( type:  Add )
# 216/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 217/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_mean ( type:  Const )
# 218/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 219/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/beta ( type:  Const )
# 220/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/beta/read ( type:  Identity )
# 221/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/gamma ( type:  Const )
# 222/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 223/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/batchnorm/mul ( type:  Mul )
# 224/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 225/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/batchnorm/sub ( type:  Sub )
# 226/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/depthwise_weights ( type:  Const )
# 227/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/depthwise_weights/read ( type:  Identity )
# 228/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/batchnorm/add/y ( type:  Const )
# 229/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_variance ( type:  Const )
# 230/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_variance/read ( type:  Identity )
# 231/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/batchnorm/add ( type:  Add )
# 232/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 233/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_mean ( type:  Const )
# 234/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_mean/read ( type:  Identity )
# 235/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/beta ( type:  Const )
# 236/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/beta/read ( type:  Identity )
# 237/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/gamma ( type:  Const )
# 238/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/gamma/read ( type:  Identity )
# 239/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/batchnorm/mul ( type:  Mul )
# 240/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 241/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/batchnorm/sub ( type:  Sub )
# 242/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/weights ( type:  Const )
# 243/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/weights/read ( type:  Identity )
# 244/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/batchnorm/add/y ( type:  Const )
# 245/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_variance ( type:  Const )
# 246/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_variance/read ( type:  Identity )
# 247/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/batchnorm/add ( type:  Add )
# 248/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 249/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_mean ( type:  Const )
# 250/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_mean/read ( type:  Identity )
# 251/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/beta ( type:  Const )
# 252/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/beta/read ( type:  Identity )
# 253/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/gamma ( type:  Const )
# 254/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/gamma/read ( type:  Identity )
# 255/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/batchnorm/mul ( type:  Mul )
# 256/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 257/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/batchnorm/sub ( type:  Sub )
# 258/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/weights ( type:  Const )
# 259/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/weights/read ( type:  Identity )
# 260/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/batchnorm/add/y ( type:  Const )
# 261/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_variance ( type:  Const )
# 262/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 263/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/batchnorm/add ( type:  Add )
# 264/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 265/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_mean ( type:  Const )
# 266/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 267/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/beta ( type:  Const )
# 268/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/beta/read ( type:  Identity )
# 269/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/gamma ( type:  Const )
# 270/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 271/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/batchnorm/mul ( type:  Mul )
# 272/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 273/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/batchnorm/sub ( type:  Sub )
# 274/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/depthwise_weights ( type:  Const )
# 275/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/depthwise_weights/read ( type:  Identity )
# 276/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/batchnorm/add/y ( type:  Const )
# 277/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_variance ( type:  Const )
# 278/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_variance/read ( type:  Identity )
# 279/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/batchnorm/add ( type:  Add )
# 280/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 281/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_mean ( type:  Const )
# 282/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_mean/read ( type:  Identity )
# 283/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/beta ( type:  Const )
# 284/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/beta/read ( type:  Identity )
# 285/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/gamma ( type:  Const )
# 286/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/gamma/read ( type:  Identity )
# 287/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/batchnorm/mul ( type:  Mul )
# 288/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 289/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/batchnorm/sub ( type:  Sub )
# 290/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/weights ( type:  Const )
# 291/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/weights/read ( type:  Identity )
# 292/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/batchnorm/add/y ( type:  Const )
# 293/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_variance ( type:  Const )
# 294/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_variance/read ( type:  Identity )
# 295/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/batchnorm/add ( type:  Add )
# 296/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 297/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_mean ( type:  Const )
# 298/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_mean/read ( type:  Identity )
# 299/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/beta ( type:  Const )
# 300/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/beta/read ( type:  Identity )
# 301/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/gamma ( type:  Const )
# 302/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/gamma/read ( type:  Identity )
# 303/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/batchnorm/mul ( type:  Mul )
# 304/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 305/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/batchnorm/sub ( type:  Sub )
# 306/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/weights ( type:  Const )
# 307/1522: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/weights/read ( type:  Identity )
# 308/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/batchnorm/add/y ( type:  Const )
# 309/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance ( type:  Const )
# 310/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read ( type:  Identity )
# 311/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/batchnorm/add ( type:  Add )
# 312/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 313/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean ( type:  Const )
# 314/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read ( type:  Identity )
# 315/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/beta ( type:  Const )
# 316/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read ( type:  Identity )
# 317/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/gamma ( type:  Const )
# 318/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read ( type:  Identity )
# 319/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/batchnorm/mul ( type:  Mul )
# 320/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 321/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/batchnorm/sub ( type:  Sub )
# 322/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/weights ( type:  Const )
# 323/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/weights/read ( type:  Identity )
# 324/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/batchnorm/add/y ( type:  Const )
# 325/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance ( type:  Const )
# 326/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 327/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/batchnorm/add ( type:  Add )
# 328/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 329/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean ( type:  Const )
# 330/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 331/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta ( type:  Const )
# 332/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read ( type:  Identity )
# 333/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma ( type:  Const )
# 334/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 335/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/batchnorm/mul ( type:  Mul )
# 336/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 337/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/batchnorm/sub ( type:  Sub )
# 338/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise_weights ( type:  Const )
# 339/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise_weights/read ( type:  Identity )
# 340/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/batchnorm/add/y ( type:  Const )
# 341/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance ( type:  Const )
# 342/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 343/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/batchnorm/add ( type:  Add )
# 344/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 345/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean ( type:  Const )
# 346/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 347/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/beta ( type:  Const )
# 348/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/beta/read ( type:  Identity )
# 349/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/gamma ( type:  Const )
# 350/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/gamma/read ( type:  Identity )
# 351/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/batchnorm/mul ( type:  Mul )
# 352/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 353/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/batchnorm/sub ( type:  Sub )
# 354/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/weights ( type:  Const )
# 355/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/weights/read ( type:  Identity )
# 356/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/batchnorm/add/y ( type:  Const )
# 357/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_variance ( type:  Const )
# 358/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_variance/read ( type:  Identity )
# 359/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/batchnorm/add ( type:  Add )
# 360/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 361/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_mean ( type:  Const )
# 362/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_mean/read ( type:  Identity )
# 363/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/beta ( type:  Const )
# 364/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/beta/read ( type:  Identity )
# 365/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/gamma ( type:  Const )
# 366/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/gamma/read ( type:  Identity )
# 367/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/batchnorm/mul ( type:  Mul )
# 368/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 369/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/batchnorm/sub ( type:  Sub )
# 370/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/weights ( type:  Const )
# 371/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/weights/read ( type:  Identity )
# 372/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/batchnorm/add/y ( type:  Const )
# 373/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_variance ( type:  Const )
# 374/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 375/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/batchnorm/add ( type:  Add )
# 376/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 377/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_mean ( type:  Const )
# 378/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 379/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/beta ( type:  Const )
# 380/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/beta/read ( type:  Identity )
# 381/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/gamma ( type:  Const )
# 382/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 383/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/batchnorm/mul ( type:  Mul )
# 384/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 385/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/batchnorm/sub ( type:  Sub )
# 386/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/depthwise_weights ( type:  Const )
# 387/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/depthwise_weights/read ( type:  Identity )
# 388/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/batchnorm/add/y ( type:  Const )
# 389/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_variance ( type:  Const )
# 390/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 391/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/batchnorm/add ( type:  Add )
# 392/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 393/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_mean ( type:  Const )
# 394/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 395/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/beta ( type:  Const )
# 396/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/beta/read ( type:  Identity )
# 397/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/gamma ( type:  Const )
# 398/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/gamma/read ( type:  Identity )
# 399/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/batchnorm/mul ( type:  Mul )
# 400/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/batchnorm/mul_2 ( type:  Mul )
# 401/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/batchnorm/sub ( type:  Sub )
# 402/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/weights ( type:  Const )
# 403/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/weights/read ( type:  Identity )
# 404/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/batchnorm/add/y ( type:  Const )
# 405/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/moving_variance ( type:  Const )
# 406/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/moving_variance/read ( type:  Identity )
# 407/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/batchnorm/add ( type:  Add )
# 408/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/batchnorm/Rsqrt ( type:  Rsqrt )
# 409/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/moving_mean ( type:  Const )
# 410/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/moving_mean/read ( type:  Identity )
# 411/1522: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/beta ( type:  Const )
# ...
# 1505/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/Conv2D ( type:  Conv2D )
# 1506/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/mul_1 ( type:  Mul )
# 1507/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/add_1 ( type:  Add )
# 1508/1522: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/Relu6 ( type:  Relu6 )
# 1509/1522: Analysing op name: BoxPredictor_5/Shape ( type:  Shape )
# 1510/1522: Analysing op name: BoxPredictor_5/strided_slice ( type:  StridedSlice )
# 1511/1522: Analysing op name: BoxPredictor_5/stack_1 ( type:  Pack )
# 1512/1522: Analysing op name: BoxPredictor_5/stack ( type:  Pack )
# 1513/1522: Analysing op name: BoxPredictor_5/ClassPredictor/Conv2D ( type:  Conv2D )
# 1514/1522: Analysing op name: BoxPredictor_5/ClassPredictor/BiasAdd ( type:  BiasAdd )
# 1515/1522: Analysing op name: BoxPredictor_5/Reshape_1 ( type:  Reshape )
# 1516/1522: Analysing op name: concat_1 ( type:  ConcatV2 )
# 1517/1522: Analysing op name: Postprocessor/scale_logits ( type:  RealDiv )
# 1518/1522: Analysing op name: Postprocessor/convert_scores ( type:  Sigmoid )
# 1519/1522: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/Conv2D ( type:  Conv2D )
# 1520/1522: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/BiasAdd ( type:  BiasAdd )
# 1521/1522: Analysing op name: BoxPredictor_5/Reshape ( type:  Reshape )
# 1522/1522: Analysing op name: concat ( type:  ConcatV2 )
# Translation to CoreML spec completed. Now compiling and saving the CoreML model.
#
#  Core ML model generated. Saved at location: SSDMobileNetV2.mlmodel
#
# Core ML input(s):
#  [name: "Preprocessor__sub__0"
# type {
#   imageType {
#     width: 300
#     height: 300
#     colorSpace: RGB
#   }
# }
# ]
# Core ML output(s):
#  [name: "Postprocessor__convert_scores__0"
# type {
#   multiArrayType {
#     dataType: DOUBLE
#   }
# }
# , name: "concat__0"
# type {
#   multiArrayType {
#     shape: 4
#     shape: 1917
#     shape: 1
#     dataType: DOUBLE
#   }
# }
# ]
# /usr/local/lib/python3.7/dist-packages/coremltools/models/_deprecation.py:25: FutureWarning: Function "convert_neural_network_spec_weights_to_fp16" is deprecated and will be removed in the next release; instead use 'coremltools.models.neural_network.quantization_utils.quantize_weights'.
#   warnings.warn(msg, category=FutureWarning)
# Quantizing layer FeatureExtractor/MobilenetV2/Conv/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/Conv/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_1/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_1/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_1/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_1/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_2/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_2/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_2/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_2/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_3/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_3/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_3/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_3/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_4/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_4/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_4/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_4/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_5/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_5/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_5/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_5/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_6/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_6/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_6/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_6/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_7/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_7/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_7/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_7/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_8/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_8/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_8/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_8/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_9/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_9/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_9/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_9/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_10/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_10/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_10/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_10/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_11/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_11/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_11/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_11/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_12/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_12/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_12/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_12/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_13/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_13/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer BoxPredictor_0/ClassPredictor/Conv2D:0
# Quantizing layer BoxPredictor_0/ClassPredictor/BiasAdd:0
# Quantizing layer BoxPredictor_0/BoxEncodingPredictor/Conv2D:0
# Quantizing layer BoxPredictor_0/BoxEncodingPredictor/BiasAdd:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_13/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_13/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_14/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_14/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_14/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_15/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_15/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_16/expand/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_16/project/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/Conv_1/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/batchnorm/add_1:0
# Quantizing layer BoxPredictor_1/ClassPredictor/Conv2D:0
# Quantizing layer BoxPredictor_1/ClassPredictor/BiasAdd:0
# Quantizing layer BoxPredictor_1/BoxEncodingPredictor/Conv2D:0
# Quantizing layer BoxPredictor_1/BoxEncodingPredictor/BiasAdd:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/batchnorm/add_1:0
# Quantizing layer BoxPredictor_2/ClassPredictor/Conv2D:0
# Quantizing layer BoxPredictor_2/ClassPredictor/BiasAdd:0
# Quantizing layer BoxPredictor_2/BoxEncodingPredictor/Conv2D:0
# Quantizing layer BoxPredictor_2/BoxEncodingPredictor/BiasAdd:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/batchnorm/add_1:0
# Quantizing layer BoxPredictor_3/ClassPredictor/Conv2D:0
# Quantizing layer BoxPredictor_3/ClassPredictor/BiasAdd:0
# Quantizing layer BoxPredictor_3/BoxEncodingPredictor/Conv2D:0
# Quantizing layer BoxPredictor_3/BoxEncodingPredictor/BiasAdd:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/batchnorm/add_1:0
# Quantizing layer BoxPredictor_4/ClassPredictor/Conv2D:0
# Quantizing layer BoxPredictor_4/ClassPredictor/BiasAdd:0
# Quantizing layer BoxPredictor_4/BoxEncodingPredictor/Conv2D:0
# Quantizing layer BoxPredictor_4/BoxEncodingPredictor/BiasAdd:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/depthwise:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/batchnorm/add_1:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/Conv2D:0
# Quantizing layer FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/batchnorm/add_1:0
# Quantizing layer BoxPredictor_5/ClassPredictor/Conv2D:0
# Quantizing layer BoxPredictor_5/ClassPredictor/BiasAdd:0
# Quantizing layer BoxPredictor_5/BoxEncodingPredictor/Conv2D:0
# Quantizing layer BoxPredictor_5/BoxEncodingPredictor/BiasAdd:0
# input {
#   name: "image"
#   shortDescription: "Input image"
#   type {
#     imageType {
#       width: 300
#       height: 300
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "scores"
#   shortDescription: "Predicted class scores for each bounding box"
#   type {
#     multiArrayType {
#       shape: 91
#       shape: 1917
#       dataType: DOUBLE
#     }
#   }
# }
# output {
#   name: "boxes"
#   shortDescription: "Predicted coordinates for each bounding box"
#   type {
#     multiArrayType {
#       shape: 4
#       shape: 1917
#       dataType: DOUBLE
#     }
#   }
# }

# %%
# ================================
# PART 2: Decoding the coordinates
# ================================

def get_anchors(graph, tensor_name):
    """
    Computes the list of anchor boxes by sending a fake image through the graph.
    Outputs an array of size (4, num_anchors) where each element is an anchor box
    given as [ycenter, xcenter, height, width] in normalized coordinates.
    """
    image_tensor = graph.get_tensor_by_name("image_tensor:0")
    box_corners_tensor = graph.get_tensor_by_name(tensor_name)
    box_corners = sess.run(box_corners_tensor, feed_dict={image_tensor: np.zeros((1, input_height, input_width, 3))})

    # The TensorFlow graph gives each anchor box as [ymin, xmin, ymax, xmax]. 
    # Convert these min/max values to a center coordinate, width and height.
    ymin, xmin, ymax, xmax = np.transpose(box_corners)
    width = xmax - xmin
    height = ymax - ymin
    ycenter = ymin + height / 2.
    xcenter = xmin + width / 2.
    return np.stack([ycenter, xcenter, height, width])


# Read the anchors into a (4, 1917) tensor.
anchors_tensor = "Concatenate/concat:0"
with the_graph.as_default():
    with tf.Session(graph=the_graph) as sess:
        anchors = get_anchors(the_graph, anchors_tensor)
        assert(anchors.shape[1] == num_anchors)


from coremltools.models import datatypes
from coremltools.models import neural_network

# MLMultiArray inputs of neural networks must have 1 or 3 dimensions. 
# We only have 2, so add an unused dimension of size one at the back.
input_features = [ ("scores", datatypes.Array(num_classes + 1, num_anchors, 1)),
                   ("boxes", datatypes.Array(4, num_anchors, 1)) ]

# The outputs of the decoder model should match the inputs of the next
# model in the pipeline, NonMaximumSuppression. This expects the number
# of bounding boxes in the first dimension.
output_features = [ ("raw_confidence", datatypes.Array(num_anchors, num_classes)),
                    ("raw_coordinates", datatypes.Array(num_anchors, 4)) ]

builder = neural_network.NeuralNetworkBuilder(input_features, output_features)

# (num_classes+1, num_anchors, 1) --> (1, num_anchors, num_classes+1)
builder.add_permute(name="permute_scores",
                    dim=(0, 3, 2, 1),
                    input_name="scores",
                    output_name="permute_scores_output")

# Strip off the "unknown" class (at index 0).
builder.add_slice(name="slice_scores",
                  input_name="permute_scores_output",
                  output_name="raw_confidence",
                  axis="width",
                  start_index=1,
                  end_index=num_classes + 1)

# Grab the y, x coordinates (channels 0-1).
builder.add_slice(name="slice_yx",
                  input_name="boxes",
                  output_name="slice_yx_output",
                  axis="channel",
                  start_index=0,
                  end_index=2)

# boxes_yx / 10
builder.add_elementwise(name="scale_yx",
                        input_names="slice_yx_output",
                        output_name="scale_yx_output",
                        mode="MULTIPLY",
                        alpha=0.1)

# Split the anchors into two (2, 1917, 1) arrays.
anchors_yx = np.expand_dims(anchors[:2, :], axis=-1)
anchors_hw = np.expand_dims(anchors[2:, :], axis=-1)

builder.add_load_constant(name="anchors_yx",
                          output_name="anchors_yx",
                          constant_value=anchors_yx,
                          shape=[2, num_anchors, 1])

builder.add_load_constant(name="anchors_hw",
                          output_name="anchors_hw",
                          constant_value=anchors_hw,
                          shape=[2, num_anchors, 1])

# (boxes_yx / 10) * anchors_hw
builder.add_elementwise(name="yw_times_hw",
                        input_names=["scale_yx_output", "anchors_hw"],
                        output_name="yw_times_hw_output",
                        mode="MULTIPLY")

# (boxes_yx / 10) * anchors_hw + anchors_yx
builder.add_elementwise(name="decoded_yx",
                        input_names=["yw_times_hw_output", "anchors_yx"],
                        output_name="decoded_yx_output",
                        mode="ADD")

# Grab the height and width (channels 2-3).
builder.add_slice(name="slice_hw",
                  input_name="boxes",
                  output_name="slice_hw_output",
                  axis="channel",
                  start_index=2,
                  end_index=4)

# (boxes_hw / 5)
builder.add_elementwise(name="scale_hw",
                        input_names="slice_hw_output",
                        output_name="scale_hw_output",
                        mode="MULTIPLY",
                        alpha=0.2)

# exp(boxes_hw / 5)
builder.add_unary(name="exp_hw",
                  input_name="scale_hw_output",
                  output_name="exp_hw_output",
                  mode="exp")

# exp(boxes_hw / 5) * anchors_hw
builder.add_elementwise(name="decoded_hw",
                        input_names=["exp_hw_output", "anchors_hw"],
                        output_name="decoded_hw_output",
                        mode="MULTIPLY")

# The coordinates are now (y, x) and (height, width) but NonMaximumSuppression
# wants them as (x, y, width, height). So create four slices and then concat
# them into the right order.
builder.add_slice(name="slice_y",
                  input_name="decoded_yx_output",
                  output_name="slice_y_output",
                  axis="channel",
                  start_index=0,
                  end_index=1)

builder.add_slice(name="slice_x",
                  input_name="decoded_yx_output",
                  output_name="slice_x_output",
                  axis="channel",
                  start_index=1,
                  end_index=2)

builder.add_slice(name="slice_h",
                  input_name="decoded_hw_output",
                  output_name="slice_h_output",
                  axis="channel",
                  start_index=0,
                  end_index=1)

builder.add_slice(name="slice_w",
                  input_name="decoded_hw_output",
                  output_name="slice_w_output",
                  axis="channel",
                  start_index=1,
                  end_index=2)

builder.add_elementwise(name="concat",
                        input_names=["slice_x_output", "slice_y_output", 
                                     "slice_w_output", "slice_h_output"],
                        output_name="concat_output",
                        mode="CONCAT")

# (4, num_anchors, 1) --> (1, num_anchors, 4)
builder.add_permute(name="permute_output",
                    dim=(0, 3, 2, 1),
                    input_name="concat_output",
                    output_name="raw_coordinates")

decoder_model = ct.models.MLModel(builder.spec)
decoder_model.save("Decoder.mlmodel")

print(decoder_model)
# Out:
# input {
#   name: "scores"
#   type {
#     multiArrayType {
#       shape: 91
#       shape: 1917
#       shape: 1
#       dataType: DOUBLE
#     }
#   }
# }
# input {
#   name: "boxes"
#   type {
#     multiArrayType {
#       shape: 4
#       shape: 1917
#       shape: 1
#       dataType: DOUBLE
#     }
#   }
# }
# output {
#   name: "raw_confidence"
#   type {
#     multiArrayType {
#       shape: 1917
#       shape: 90
#       dataType: DOUBLE
#     }
#   }
# }
# output {
#   name: "raw_coordinates"
#   type {
#     multiArrayType {
#       shape: 1917
#       shape: 4
#       dataType: DOUBLE
#     }
#   }
# }

# %%
# ===============================
# PART 3: Non-maximum suppression
# ===============================

nms_spec = ct.proto.Model_pb2.Model()
nms_spec.specificationVersion = 3

for i in range(2):
    decoder_output = decoder_model._spec.description.output[i].SerializeToString()

    nms_spec.description.input.add()
    nms_spec.description.input[i].ParseFromString(decoder_output)

    nms_spec.description.output.add()
    nms_spec.description.output[i].ParseFromString(decoder_output)
    
nms_spec.description.output[0].name = "confidence"
nms_spec.description.output[1].name = "coordinates"

output_sizes = [num_classes, 4]
for i in range(2):
    ma_type = nms_spec.description.output[i].type.multiArrayType
    ma_type.shapeRange.sizeRanges.add()
    ma_type.shapeRange.sizeRanges[0].lowerBound = 0
    ma_type.shapeRange.sizeRanges[0].upperBound = -1
    ma_type.shapeRange.sizeRanges.add()
    ma_type.shapeRange.sizeRanges[1].lowerBound = output_sizes[i]
    ma_type.shapeRange.sizeRanges[1].upperBound = output_sizes[i]
    del ma_type.shape[:]

nms = nms_spec.nonMaximumSuppression
nms.confidenceInputFeatureName = "raw_confidence"
nms.coordinatesInputFeatureName = "raw_coordinates"
nms.confidenceOutputFeatureName = "confidence"
nms.coordinatesOutputFeatureName = "coordinates"
nms.iouThresholdInputFeatureName = "iouThreshold"
nms.confidenceThresholdInputFeatureName = "confidenceThreshold"

default_iou_threshold = 0.6
default_confidence_threshold = 0.4
nms.iouThreshold = default_iou_threshold
nms.confidenceThreshold = default_confidence_threshold

nms.pickTop.perClass = True

labels = np.loadtxt("coco_labels.txt", dtype=str, delimiter="\n")
nms.stringClassLabels.vector.extend(labels)

nms_model = ct.models.MLModel(nms_spec)
nms_model.save("NMS.mlmodel")

print(nms_model)
# Out:
# input {
#   name: "raw_confidence"
#   type {
#     multiArrayType {
#       shape: 1917
#       shape: 90
#       dataType: DOUBLE
#     }
#   }
# }
# input {
#   name: "raw_coordinates"
#   type {
#     multiArrayType {
#       shape: 1917
#       shape: 4
#       dataType: DOUBLE
#     }
#   }
# }
# output {
#   name: "confidence"
#   type {
#     multiArrayType {
#       dataType: DOUBLE
#       shapeRange {
#         sizeRanges {
#           upperBound: -1
#         }
#         sizeRanges {
#           lowerBound: 90
#           upperBound: 90
#         }
#       }
#     }
#   }
# }
# output {
#   name: "coordinates"
#   type {
#     multiArrayType {
#       dataType: DOUBLE
#       shapeRange {
#         sizeRanges {
#           upperBound: -1
#         }
#         sizeRanges {
#           lowerBound: 4
#           upperBound: 4
#         }
#       }
#     }
#   }
# }

# %%
# ===============================================
# PART 4: Putting it all together into a pipeline
# ===============================================

from coremltools.models.pipeline import *

input_features = [ ("image", datatypes.Array(3, 300, 300)),
                   ("iouThreshold", datatypes.Double()),
                   ("confidenceThreshold", datatypes.Double()) ]

output_features = [ "confidence", "coordinates" ]

pipeline = Pipeline(input_features, output_features)

# We added a dimension of size 1 to the back of the inputs of the decoder 
# model, so we should also add this to the output of the SSD model or else 
# the inputs and outputs do not match and the pipeline is not valid.
ssd_output = ssd_model._spec.description.output
ssd_output[0].type.multiArrayType.shape[:] = [num_classes + 1, num_anchors, 1]
ssd_output[1].type.multiArrayType.shape[:] = [4, num_anchors, 1]

pipeline.add_model(ssd_model)
pipeline.add_model(decoder_model)
pipeline.add_model(nms_model)

# The "image" input should really be an image, not a multi-array.
pipeline.spec.description.input[0].ParseFromString(ssd_model._spec.description.input[0].SerializeToString())

# Copy the declarations of the "confidence" and "coordinates" outputs.
# The Pipeline makes these strings by default.
pipeline.spec.description.output[0].ParseFromString(nms_model._spec.description.output[0].SerializeToString())
pipeline.spec.description.output[1].ParseFromString(nms_model._spec.description.output[1].SerializeToString())

# Add descriptions to the inputs and outputs.
pipeline.spec.description.input[1].shortDescription = f"(optional) IOU Threshold override (default={default_iou_threshold}"
pipeline.spec.description.input[2].shortDescription = f"(optional) Confidence Threshold override (default={default_confidence_threshold})"
pipeline.spec.description.output[0].shortDescription = u"Boxes \xd7 Class confidence"
pipeline.spec.description.output[1].shortDescription = u"Boxes \xd7 [x, y, width, height] (relative to image size)"

# Add metadata to the model.
pipeline.spec.description.metadata.versionString = "ssd_mobilenet_v2_coco_2018_03_29"
pipeline.spec.description.metadata.shortDescription = """
MobileNetV2 + SSD, trained on COCO. Source: http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_coco_2018_03_29.tar.gz
"""
pipeline.spec.description.metadata.author = "Converted to Core ML by Anh"
pipeline.spec.description.metadata.license = "https://github.com/tensorflow/models/blob/master/research/object_detection"

# Add the list of class labels and the default threshold values too.
user_defined_metadata = {
    "iou_threshold": str(default_iou_threshold),
    "confidence_threshold": str(default_confidence_threshold),
    "classes": ",".join(labels)
}
pipeline.spec.description.metadata.userDefined.update(user_defined_metadata)

# Don't forget this or Core ML might attempt to run the model on an unsupported
# operating system version!
pipeline.spec.specificationVersion = 3

final_model = ct.models.MLModel(pipeline.spec)
final_model.save(coreml_model_path)

print(final_model)
print("Done!")
# Out:
# input {
#   name: "image"
#   shortDescription: "Input image"
#   type {
#     imageType {
#       width: 300
#       height: 300
#       colorSpace: RGB
#     }
#   }
# }
# input {
#   name: "iouThreshold"
#   shortDescription: "(optional) IOU Threshold override (default=0.6"
#   type {
#     doubleType {
#     }
#   }
# }
# input {
#   name: "confidenceThreshold"
#   shortDescription: "(optional) Confidence Threshold override (default=0.4)"
#   type {
#     doubleType {
#     }
#   }
# }
# output {
#   name: "confidence"
#   shortDescription: "Boxes \303\227 Class confidence"
#   type {
#     multiArrayType {
#       dataType: DOUBLE
#       shapeRange {
#         sizeRanges {
#           upperBound: -1
#         }
#         sizeRanges {
#           lowerBound: 90
#           upperBound: 90
#         }
#       }
#     }
#   }
# }
# output {
#   name: "coordinates"
#   shortDescription: "Boxes \303\227 [x, y, width, height] (relative to image size)"
#   type {
#     multiArrayType {
#       dataType: DOUBLE
#       shapeRange {
#         sizeRanges {
#           upperBound: -1
#         }
#         sizeRanges {
#           lowerBound: 4
#           upperBound: 4
#         }
#       }
#     }
#   }
# }
# metadata {
#   shortDescription: "\nMobileNetV2 + SSD, trained on COCO. Source: http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_coco_2018_03_29.tar.gz\n"
#   versionString: "ssd_mobilenet_v2_coco_2018_03_29"
#   author: "Converted to Core ML by Anh"
#   license: "https://github.com/tensorflow/models/blob/master/research/object_detection"
#   userDefined {
#     key: "classes"
#     value: "person,bicycle,car,motorcycle,airplane,bus,train,truck,boat,traffic light,fire hydrant,?,stop sign,parking meter,bench,bird,cat,dog,horse,sheep,cow,elephant,bear,zebra,giraffe,?,backpack,umbrella,?,?,handbag,tie,suitcase,frisbee,skis,snowboard,sports ball,kite,baseball bat,baseball glove,skateboard,surfboard,tennis racket,bottle,?,wine glass,cup,fork,knife,spoon,bowl,banana,apple,sandwich,orange,broccoli,carrot,hot dog,pizza,donut,cake,chair,couch,potted plant,bed,?,dining table,?,?,toilet,?,tv,laptop,mouse,remote,keyboard,cell phone,microwave,oven,toaster,sink,refrigerator,?,book,clock,vase,scissors,teddy bear,hair drier,toothbrush"
#   }
#   userDefined {
#     key: "confidence_threshold"
#     value: "0.4"
#   }
#   userDefined {
#     key: "iou_threshold"
#     value: "0.6"
#   }
# }
#
# Done!
